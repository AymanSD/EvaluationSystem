# %%
import pandas as pd
import openpyxl
from sqlalchemy import create_engine, text
from datetime import datetime, timedelta
import pyodbc
import urllib.parse

# %% [markdown]
# ### Functions

# %%
regions_dict= {
    'Makka': ['مكة المكرمة', 'الجموم', 'جدة', 'بحرة'], 'Madinah':['المدينة المنورة'],
    'Riyadh': ['الرياض', 'المزاحمية', 'الدرعية', 'حريملاء','مرات', "القويعية", 'الخرج', 'الدلم', 'الزلفى', 'الغاط', 'المجمعه', 
                'جلاجل','حوطة سدير', 'روضة سدير', 'الرين', 'الافلاج', 'السليل', 'ضرماء', 'رماح', 'ثادق', 'عفيف', 'وادى الدواسر',
                'الدوادمي', 'ساجر'],
    'Eastern': ['الدمام', 'الخبر', 'القطيف', 'الاحساء', 'الجبيل','النعيرية', 'ابقيق', 'راس تنوره', 'الخفجي',"حفر الباطن", "القيصومة"],
    'Qasim':['بريدة','رياض الخبراء','عنيزة','الرس','البكيرية','البدائع', 'البطين', 'الخبراء والسحابين', 'عيون الجواء', 'القوارة', 'الشماسية', 'المذنب', 'الاسياح'],
    "Hael":["حائل", 'بقعاء', 'الشنان', 'جبة', 'موقق', 'الشملي', 'الغزالة', 'الحائط', 'سميراء', 'السليمي'],
    "Tabuk": ['تبوك','الوجه', 'تيماء', 'ضباء', 'املج'],
    "Jawf": ['دومة الجندل', 'صوير', 'سكاكا', 'القريات', 'طبرجل', 'العيساوية'],
    "Northern Borders": ['رفحاء', 'عرعر', 'طريف', 'العويقيلة']} 


geoActions = {'البيانات الجيومكانية صحيحة':['الجيومكانية صحيحة', 'الجيومكانية صحيحه', 'الجيومكانيه صحيحه', 'جيومكانية صحيحة'],'تعديل بيانات وصفية':['بيانات وصفية', 'بيانات وصفيه', 'البيانات الوصفية', 'البيانات الوصفيه'], 'تعديل أبعاد الأرض':['أبعاد', 'ابعاد', 'تعديل أبعاد', 'تعديل ابعاد', 'تعديل الأبعاد', 'تعديل الابعاد'], 
                'تجزئة':['تجزئة','التجزئة'], 'دمج':['دمج', 'الدمج'], 'رفض':["يعاد", 'رفض', 'نقص','مرفوض',"مستندات", "ارفاق", "إرفاق", "غير صحيحة", "الارض المختارة غير صحيحة"]}

rejectionReasons = {'محضر الدمج/التجزئة':['محضر', 'المحضر', 'المحضر المطلوب', 'محضر اللجنة الفنية'], 
                    'إزدواجية صكوك': ['ازدواجية صكوك', 'إزدواجية صكوك', 'ازدواجيه', 'إزدواجيه صكوك'],
                    "خطأ في بيانات الصك":['خطأ في بيانات الصك', 'خطأ في الصك'],
                    'صك الأرض':['صك الأرض', 'صك الارض', 'صك', 'الصك'], 
                    "إرفاق المؤشرات":["مؤشرات", "إرفاق كافه المؤشرات", "ارفاق كافة المؤشرات","ارفاق كافه المؤشرات"],
                    'طلب لوحدة عقارية':['طلب لوحدة عقارية', 'وحدة', 'وحده', 'وحده عقارية', 'وحدة عقاريه', 'عقارية'], 
                    'طلب مسجل مسبقاً':['سابق', 'مسبقا', 'مسبقاً', 'مسبق', 'طلب آخر', 'مكرر', 'طلب تسجيل اول مكرر'], 'إختيار خاطئ': ['اختيار خاطئ','المختارة غير صحيحة','إختيار خاطئ','المختارة غير صحيحه'],
                    "المخطط المعتمد":["المخطط", "مخطط"]}

def getGeoAction(df):
    
    if 'City Name' in df.columns:
        df['Region'] = ''
        for regionName, cities in regions_dict.items():
            df.loc[df["City Name"].isin(cities), 'Region'] = regionName
    
    # Ensure required columns exist
    if not {'Geo Supervisor Recommendation','GEO Recommendation'}.issubset(df.columns):
        return df

    df['GeoAction'] = ''
    df['Rejection'] = ''

    for i in range(len(df)):
        recomm = df.at[i, 'Geo Supervisor Recommendation']
        recomm2 = df.at[i, 'GEO Recommendation']

        # Normalize empty values
        if pd.isna(recomm) or recomm == '':
            recomm = recomm2
        if pd.isna(recomm) or recomm == '':
            df.at[i, 'GeoAction'] = 'No Action'
            continue

        text = str(recomm)

        action_found = False

        # -----------------------------------------------------
        # 1️⃣ FIRST: check all official actions from geoActions
        # -----------------------------------------------------
        for action, keywords in geoActions.items():
            if any(k in text for k in keywords):
                df.at[i, 'GeoAction'] = action
                action_found = True

                # If it is a rejection, also check reasons
                if action == 'رفض':
                    for reject, r_words in rejectionReasons.items():
                        if any(k in text for k in r_words):
                            df.at[i, 'Rejection'] = reject

                break  # stop scanning actions once matched

        # -----------------------------------------------------
        # 2️⃣ If no official action found, check “شطفة”
        # -----------------------------------------------------
        if not action_found:
            if any(k in text for k in ['شطفة', 'الشطفة', 'شطفه']):
                df.at[i, 'GeoAction'] = 'شطفة'
                continue

        # -----------------------------------------------------
        # 3️⃣ If still nothing, check “غرفة كهرباء”
        # -----------------------------------------------------
        if not action_found:
            if any(k in text for k in ['كهرب', 'غرف', 'غرفة كهرباء', 'غرفة الكهرباء', 'غرفة', 'الكهرباء']):
                df.at[i, 'GeoAction'] = 'غرفة كهرباء'
                continue

        # -----------------------------------------------------
        # 4️⃣ If still no match → No Action
        # -----------------------------------------------------
        if not action_found:
            df.at[i, 'GeoAction'] = 'No Action'

    return df

def calculate_sla(row, work_dates):
    trans_date = row[0]
    comp_date = row[1]
    try:
        period = int((comp_date - trans_date).days)
        
        sla = 0
        for i in range(period):
            current_date = trans_date + timedelta(days=i)
            if current_date in work_dates:
                sla += 1
            else:
                pass
        return int(sla)
    except:
        return None
    

def load_excel(filename):
    wb = openpyxl.load_workbook(filename, read_only=True)
    ws = wb['Sheet1']
    header_row_idx = None
    for i, row in enumerate(ws.iter_rows(max_col=2, max_row=10, values_only=True)):
        if row and 'Case Number' in row:
            header_row_idx = i
            break
    wb.close()
    if header_row_idx is not None:
        df = pd.read_excel(filename, sheet_name='Sheet1', skiprows=header_row_idx)
        return df
    else:
        raise ValueError(f"Header row with 'Case Number' not found in: {filename}")
    
def convert_to_date(df):
    dtimeFields = ['Case Date', 'Case Submission Date','Latest Action Date','Transferred to Geospatial','GEO Completion','GEO S Completion','Transferred to Ops', 'Attachment Added Date', "ListDate"]
    for field in dtimeFields:
        if field in df.columns:
            df[field] = pd.to_datetime(df[field]).dt.date
    return df

# %%
def getGeoAction(df):
    if 'City Name' in df.columns:
        df['Region'] = ''
        for regionName, cities in regions_dict.items():
            df.loc[df["City Name"].isin(cities), 'Region'] = regionName
            
    # Ensure required columns exist
    if not {'Geo Supervisor Recommendation','GEO Recommendation'}.issubset(df.columns):
        return df

    df['GeoAction'] = ''
    df['Rejection'] = ''

    def classify_row(row):

        recomm = row['Geo Supervisor Recommendation']
        recomm2 = row['GEO Recommendation']

        # Fallback to GEO Recommendation if supervisor is empty
        if pd.isna(recomm) or recomm == '':
            recomm = recomm2

        if pd.isna(recomm) or recomm == '':
            return pd.Series(['No Action', ''])

        text = str(recomm).strip()
        first_words = " ".join(text.split()[:3])

        # -----------------------------------------------------
        # 1️⃣ Highest Priority: Rejection (يعاد)
        # -----------------------------------------------------
        if first_words.startswith("يعاد") or text.startswith("يعاد"):
            
            rejection_reason = ''
            for reject, r_words in rejectionReasons.items():
                if any(k in text for k in r_words):
                    rejection_reason = reject
                    break

            return pd.Series(['رفض', rejection_reason])

        # -----------------------------------------------------
        # 2️⃣ Second Priority: Completed Action (تم)
        # -----------------------------------------------------
        if first_words.startswith("تم") or text.startswith("تم"):

            for action, keywords in geoActions.items():
                if action == 'رفض':
                    continue
                if any(k in text for k in keywords):
                    return pd.Series([action, ''])

            return pd.Series(['Action Completed', ''])

        # -----------------------------------------------------
        # 3️⃣ Fallback: Normal geoActions keyword scan
        # -----------------------------------------------------
        for action, keywords in geoActions.items():
            if any(k in text for k in keywords):

                rejection_reason = ''
                if action == 'رفض':
                    for reject, r_words in rejectionReasons.items():
                        if any(k in text for k in r_words):
                            rejection_reason = reject
                            break

                return pd.Series([action, rejection_reason])

        # -----------------------------------------------------
        # 4️⃣ Special Cases
        # -----------------------------------------------------
        if any(k in text for k in ['شطفة','الشطفة','شطفه']):
            return pd.Series(['شطفة',''])

        if any(k in text for k in ['كهرب','غرف','غرفة كهرباء','غرفة الكهرباء','غرفة','الكهرباء']):
            return pd.Series(['غرفة كهرباء',''])

        # -----------------------------------------------------
        # 5️⃣ Default
        # -----------------------------------------------------
        return pd.Series(['No Action',''])

    df[['GeoAction','Rejection']] = df.apply(classify_row, axis=1)

    return df

# %% [markdown]
# ### DB Configurations

# %%
# Define config at the top of the file
AppDB_CONFIG = {
    "server": '0003-MAAL-01\\LASSQLSERVER',
    "database": 'LASCaseWorkerApp',
    "username": 'LASCaseWorker',
    "password": 'LASCaseWorker'
}

# Utility function to create a connection
def get_connection_Sql():
    return pyodbc.connect(
        f"DRIVER={{SQL Server}};"
        f"SERVER={AppDB_CONFIG['server']};"
        f"DATABASE={AppDB_CONFIG['database']};"
        f"UID={AppDB_CONFIG['username']};"
        f"PWD={AppDB_CONFIG['password']};"
    )

## Dashboard DB SQL
DashDB_CONFIG = {
    "server": '0003-MAAL-01\\LASSQLSERVER',
    "database": 'GRSDASHBOARD',
    "username": 'lasapp',
    "password": 'lasapp@LAS123'
}

# Build ODBC connection string from existing DB_CONFIG
odbc_params = (
    "DRIVER={ODBC Driver 17 for SQL Server};"
    f"SERVER={DashDB_CONFIG['server']};"
    f"DATABASE={DashDB_CONFIG['database']};"
    f"UID={DashDB_CONFIG['username']};"
    f"PWD={DashDB_CONFIG['password']};"
)

DashPost = {
    "server":"127.0.0.1",
    "port": '5432',
    "database": "GSA",
    "username": "postgres",
    "password": "1234"
}
## Dashboard DB PostgreSQL
connection_str_post = f"postgresql://{DashPost['username']}:{DashPost['password']}@{DashPost['server']}:{DashPost['port']}/{DashPost['database']}"

# %%
odbc_connect_str = urllib.parse.quote_plus(odbc_params)
# Create SQLAlchemy engine for SQL Server via pyodbc
engine_sqlserver = create_engine(f"mssql+pyodbc:///?odbc_connect={odbc_connect_str}", fast_executemany=True)
engine_postgres = create_engine(connection_str_post)
engine_postgres2 = create_engine("postgresql://postgres:1234@localhost:5432/GRS")
tables = ['ApprovedCases', 'CR_Current', 'CR_Data', 'ClassificationData', 'CurrentCases', 'EditorsList', 'GeoData', 'GeoSCompletionData', 'HistoricalData', 'MG_Current', 'MG_Data', 'OpsData', 'RejectedCancelled', 'ReturnedCases', 'SR_Current', 'SR_Data', 'ST_EditorList', 'Ticketing', 'TransferToGeoData', 'Urgent', 'VIP',]

# %%
# # query_sql = """SELECT * FROM grsdbrd."{}" """
# query_post = """SELECT * FROM public."{}" """

def join_userlist(comp_df, editorlist):
    comp_df['GEO S Completion'] = pd.to_datetime(comp_df['GEO S Completion']).dt.normalize()
    editorlist = editorlist.rename({'CasePortalName': 'Geo Supervisor'},axis=1)
    editorlist["ListDate"] = pd.to_datetime(editorlist["ListDate"]).dt.normalize()
    comp_df = comp_df.sort_values(by=["GEO S Completion", "Geo Supervisor"])
    editorlist = editorlist.sort_values(by=["ListDate", "Geo Supervisor"])
    comp_df = pd.merge_asof(comp_df, editorlist, by="Geo Supervisor", left_on="GEO S Completion", 
                            right_on="ListDate", direction='backward')
    comp_df['GEO S Completion'] = [pd.to_datetime(i).date() for i in comp_df['GEO S Completion']]
    comp_df['ListDate'] = [pd.to_datetime(i).date() for i in comp_df['ListDate']]
    return comp_df


# def generate_evaluation_sheet(engine, start_date, end_date):
#     query = query_post+ """WHERE "GEO S Completion" BETWEEN '{}' AND '{}' """
#     value = query.format(tables[7], str(start_date), str(end_date))
#     completed = convert_to_date(pd.read_sql(value, engine))
#     editorList = convert_to_date(pd.read_sql(query_post.format(tables[5]), engine_postgres))
#     completed = join_userlist(completed, editorList)
#     # completed = completed.dropna('Geo Supervisor Recommendation')
#     return completed[~completed['Geo Supervisor Recommendation'].str.contains('يعاد')]
# # end = datetime.now().date()
# end = pd.to_datetime('2025-09-15').date()
# start = end - timedelta(days=7)
# compCases = generate_evaluation_sheet(engine_postgres,start, end)

# %%
# engine_postgres2 = create_engine("postgresql://postgres:1234@localhost:5432/GRS")
# evaluationCases.to_sql("OpsData", engine_postgres2, schema='evaluation', if_exists="replace", index=False)

# %%
# import os
# ops = load_excel(r"\\10.150.40.49\las\Anas Alhares\NewTeam\E and C Final Folder 08092024\Case Editing and Classification\Editor Team\07-Raw Data\03-PBI Data\12-Dec\267-28-Dec 2025\Ops Data 28 Dec 2025.xlsx")
# print(len(ops))
# ops = ops.drop_duplicates(subset="Case Number")
# print(len(ops))
# ops = ops[(ops['Geo Supervisor'].notnull())& (ops['GEO S Completion'].notnull())].reset_index(drop=True)
# print(len(ops))
# ops["UniqueKey"] = [str(i) + '_' + str(pd.to_datetime(j).round('s'))  for i, j in zip(ops["Case Number"].values, ops["GEO S Completion"].values)]
# ops["UploadDate"] = datetime.now().date()
# ops["UploadedBy"] = os.getlogin()
# ops = convert_to_date(ops)
# ops = getGeoAction(ops)
# ops.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[87], line 2
#       1 import os
# ----> 2 ops = load_excel(r"\\10.150.40.49\las\Anas Alhares\NewTeam\E and C Final Folder 08092024\Case Editing and Classification\Editor Team\07-Raw Data\03-PBI Data\12-Dec\267-28-Dec 2025\Ops Data 28 Dec 2025.xlsx")
#       3 print(len(ops))
#       4 ops = ops.drop_duplicates(subset="Case Number")
#
# Cell In[82], line 113, in load_excel(filename)
#     112 def load_excel(filename):
# --> 113     wb = openpyxl.load_workbook(filename, read_only=True)
#     114     ws = wb['Sheet1']
#     115     header_row_idx = None
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\openpyxl\reader\excel.py:346, in load_workbook(filename, read_only, keep_vba, data_only, keep_links, rich_text)
#     316 def load_workbook(filename, read_only=False, keep_vba=KEEP_VBA,
#     317                   data_only=False, keep_links=True, rich_text=False):
#     318     """Open the given filename and return the workbook
#     319
#     320     :param filename: the path to open or a file-like object
#    (...)    344
#     345     """
# --> 346     reader = ExcelReader(filename, read_only, keep_vba,
#     347                          data_only, keep_links, rich_text)
#     348     reader.read()
#     349     return reader.wb
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\openpyxl\reader\excel.py:123, in ExcelReader.__init__(self, fn, read_only, keep_vba, data_only, keep_links, rich_text)
#     121 def __init__(self, fn, read_only=False, keep_vba=KEEP_VBA,
#     122              data_only=False, keep_links=True, rich_text=False):
# --> 123     self.archive = _validate_archive(fn)
#     124     self.valid_files = self.archive.namelist()
#     125     self.read_only = read_only
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\openpyxl\reader\excel.py:95, in _validate_archive(filename)
#      88             msg = ('openpyxl does not support %s file format, '
#      89                    'please check you can open '
#      90                    'it with Excel first. '
#      91                    'Supported formats are: %s') % (file_format,
#      92                                                    ','.join(SUPPORTED_FORMATS))
#      93         raise InvalidFileException(msg)
# ---> 95 archive = ZipFile(filename, 'r')
#      96 return archive
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\zipfile\__init__.py:1367, in ZipFile.__init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps, metadata_encoding)
#    1365 while True:
#    1366     try:
# -> 1367         self.fp = io.open(file, filemode)
#    1368     except OSError:
#    1369         if filemode in modeDict:
#
# FileNotFoundError: [Errno 2] No such file or directory: '\\\\10.150.40.49\\las\\Anas Alhares\\NewTeam\\E and C Final Folder 08092024\\Case Editing and Classification\\Editor Team\\07-Raw Data\\03-PBI Data\\12-Dec\\267-28-Dec 2025\\Ops Data 28 Dec 2025.xlsx'

# %%
# unassigned_editors = pd.read_sql("""
#     SELECT "CasePortalName" FROM evaluation."EditorsList"
# WHERE "GroupID" IN ('Editor Morning Shift', 'Editor Night Shift', 
# 		'Pod-Al-Shuhada-1', 'Pod-Al-Shuhada-2', 'Urgent Team')
# AND "CasePortalName" NOT IN (
# 	SELECT "EditorName" FROM evaluation."CaseAssignment"
# 	WHERE "AssignmentDate" = CURRENT_DATE
# )
# """, engine_postgres2)
# # unassigned_editors.head(20)

# %%
# editors_cases[editors_cases["Geo Supervisor"].isin(unassigned_editors["CasePortalName"])]

# %%
# ops[ops['GEO S Completion'].isna()][ops.columns[8:20]]

# %%
sql = """SELECT 
"City Name" COLLATE Arabic_CI_AS AS "City Name",
COUNT(*) 
FROM grsdbrd."GeoCompletion"
WHERE "City Name" COLLATE Arabic_CI_AS = N'حائل'
GROUP BY "City Name"
"""
df = pd.read_sql(sql, engine_sqlserver)
print(len(df))
# Out:
# ---------------------------------------------------------------------------
# ProgrammingError                          Traceback (most recent call last)
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ProgrammingError: ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]An expression of non-boolean type specified in a context where a condition is expected, near 'WHERE'. (4145) (SQLExecDirectW)")
#
# The above exception was the direct cause of the following exception:
#
# ProgrammingError                          Traceback (most recent call last)
# Cell In[18], line 8
#       1 sql = """SELECT
#       2 "City Name" COLLATE Arabic_CI_AS AS "City Name",
#       3 COUNT(*)
#    (...)      6 GROUP BY "City Name"
#       7 """
# ----> 8 df = pd.read_sql(sql, engine_sqlserver)
#       9 print(len(df))
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\pandas\io\sql.py:734, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     724     return pandas_sql.read_table(
#     725         sql,
#     726         index_col=index_col,
#    (...)    731         dtype_backend=dtype_backend,
#     732     )
#     733 else:
# --> 734     return pandas_sql.read_query(
#     735         sql,
#     736         index_col=index_col,
#     737         params=params,
#     738         coerce_float=coerce_float,
#     739         parse_dates=parse_dates,
#     740         chunksize=chunksize,
#     741         dtype_backend=dtype_backend,
#     742         dtype=dtype,
#     743     )
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\pandas\io\sql.py:1836, in SQLDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    1779 def read_query(
#    1780     self,
#    1781     sql: str,
#    (...)   1788     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    1789 ) -> DataFrame | Iterator[DataFrame]:
#    1790     """
#    1791     Read SQL query into a DataFrame.
#    1792
#    (...)   1834
#    1835     """
# -> 1836     result = self.execute(sql, params)
#    1837     columns = result.keys()
#    1839     if chunksize is not None:
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\pandas\io\sql.py:1659, in SQLDatabase.execute(self, sql, params)
#    1657 args = [] if params is None else [params]
#    1658 if isinstance(sql, str):
# -> 1659     return self.con.exec_driver_sql(sql, *args)
#    1660 return self.con.execute(sql, *args)
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\sqlalchemy\engine\base.py:1776, in Connection.exec_driver_sql(self, statement, parameters, execution_options)
#    1771 execution_options = self._execution_options.merge_with(
#    1772     execution_options
#    1773 )
#    1775 dialect = self.dialect
# -> 1776 ret = self._execute_context(
#    1777     dialect,
#    1778     dialect.execution_ctx_cls._init_statement,
#    1779     statement,
#    1780     None,
#    1781     execution_options,
#    1782     statement,
#    1783     distilled_parameters,
#    1784 )
#    1786 return ret
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\sqlalchemy\engine\base.py:1843, in Connection._execute_context(self, dialect, constructor, statement, parameters, execution_options, *args, **kw)
#    1841     return self._exec_insertmany_context(dialect, context)
#    1842 else:
# -> 1843     return self._exec_single_context(
#    1844         dialect, context, statement, parameters
#    1845     )
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\sqlalchemy\engine\base.py:1983, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1980     result = context._setup_result_proxy()
#    1982 except BaseException as e:
# -> 1983     self._handle_dbapi_exception(
#    1984         e, str_statement, effective_parameters, cursor, context
#    1985     )
#    1987 return result
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\sqlalchemy\engine\base.py:2352, in Connection._handle_dbapi_exception(self, e, statement, parameters, cursor, context, is_sub_exec)
#    2350 elif should_wrap:
#    2351     assert sqlalchemy_exception is not None
# -> 2352     raise sqlalchemy_exception.with_traceback(exc_info[2]) from e
#    2353 else:
#    2354     assert exc_info[1] is not None
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\sqlalchemy\engine\base.py:1964, in Connection._exec_single_context(self, dialect, context, statement, parameters)
#    1962                 break
#    1963     if not evt_handled:
# -> 1964         self.dialect.do_execute(
#    1965             cursor, str_statement, effective_parameters, context
#    1966         )
#    1968 if self._has_events or self.engine._has_events:
#    1969     self.dispatch.after_cursor_execute(
#    1970         self,
#    1971         cursor,
#    (...)   1975         context.executemany,
#    1976     )
#
# File c:\Users\Aaltoum\.conda\envs\dash\Lib\site-packages\sqlalchemy\engine\default.py:942, in DefaultDialect.do_execute(self, cursor, statement, parameters, context)
#     941 def do_execute(self, cursor, statement, parameters, context=None):
# --> 942     cursor.execute(statement, parameters)
#
# ProgrammingError: (pyodbc.ProgrammingError) ('42000', "[42000] [Microsoft][ODBC Driver 17 for SQL Server][SQL Server]An expression of non-boolean type specified in a context where a condition is expected, near 'WHERE'. (4145) (SQLExecDirectW)")
# [SQL: SELECT
# "City Name" COLLATE Arabic_CI_AS AS "City Name",
# COUNT(*)
# FROM grsdbrd."GeoCompletion" WHERE "City Name"
# WHERE "City Name" COLLATE Arabic_CI_AS = N'حائل'
# GROUP BY "City Name"
# ]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
editorlist = pd.read_sql("SELECT * FROM public.\"EditorsList\" ", engine_postgres)
editorlist = convert_to_date(editorlist)
# editorlist.head()

# %%
ops_joined = join_userlist(ops, editorlist)
# ops_final = ops_joined[ops_joined["ListDate"].notna()]
# print(len(ops_final), len(ops_joined))
# ops_joined[ops_joined.columns[8:20]].head(20)

# %%
print(f"Count of Cases: {len(ops_joined):,} \nEarliest Completion Date: {ops_joined["GEO S Completion"].min()}")
# Out:
# Count of Cases: 12,122
# Earliest Completion Date: 2025-04-30

# %%
engine_postgres2 = create_engine("postgresql://postgres:1234@localhost:5432/GRS")
# ops_joined.to_sql("OpsData", engine_postgres2, schema='evaluation', if_exists="replace", index=False)
# Out:
# 242

# %%
assignment = pd.read_sql("""SELECT "AssignedSupervisor", COUNT(*) FROM evaluation."CaseAssignment"
                         WHERE "AssignmentDate" = CURRENT_DATE
                         GROUP BY "AssignedSupervisor" """, engine_postgres2)
assignment

# %% [markdown]
# ### Combine GeoData

# %%
import os
dir = r"C:\Users\Aaltoum\Desktop\Excels\GeoData\GEO DATA"
# dir = r
files = ['/'.join([dir, i]) for i in os.listdir(dir) if i.endswith('xlsx')]
print(files)
# Out:
# ['C:\\Users\\Aaltoum\\Desktop\\Excels\\GeoData\\GEO DATA/Geo1.xlsx', 'C:\\Users\\Aaltoum\\Desktop\\Excels\\GeoData\\GEO DATA/Geo2.xlsx', 'C:\\Users\\Aaltoum\\Desktop\\Excels\\GeoData\\GEO DATA/Geo3.xlsx']

# %%
dfs = []
for i in files:
    df = load_excel(i)
    dfs.append(df)
combined_df = pd.concat(dfs)
print(len(combined_df))
combined_df = combined_df.drop_duplicates(subset="Case Number", keep='last')
print(len(combined_df))
# Out:
# 209464
# 201802
# C:\Users\Aaltoum\AppData\Local\Temp\ipykernel_26748\1907409979.py:5: FutureWarning: The behavior of DataFrame concatenation with empty or all-NA entries is deprecated. In a future version, this will no longer exclude empty or all-NA columns when determining the result dtypes. To retain the old behavior, exclude the relevant entries before the concat operation.
#   combined_df = pd.concat(dfs)

# %%
print(len(combined_df[(combined_df["REN"].isna()) | (combined_df["Case Number"].isna())]))
# Out:
# 0

# %%
combined_df[combined_df["Transferred to Geospatial"]=='NaT']
# Out:
# Empty DataFrame
# Columns: [Case Number, Absolute Ownership, Duplicate Case, Generated Titles, Case Submission Date, Latest Action Date, Action, Assignee, Transferred to Geospatial, Return To Geo Team, Count of Returns Cases , GEO Completion, GEO S Completion, Transferred to Ops, Case Status, REN, Boundary Length Deed, Boundary Length Parcel, MoJ Deed Number, Moj Real Estate Serial, MoJ Plan #, MoJ Real Estate Area, MoJ Land Number, City Name, District Name, MoJ Deed Area Text, Property Type, Parcel Area Size, Parcel Number (PCP), Location Description, Attachments, Attachment Added Date, Deed East Limit Description, Deed East Limit Length, Deed Eastern Type, Deed  West Limit Description, Deed West Limit Length, Deed Western Boarder Type, Deed North Limit Description, Deed North Limit Length, Deed Northern Boarder Type, Deed South Limit Description, Deed South Limit Length, Deed Sothern Boarder Type, CW, CW Recommendation, CWS, CWS Recommendation, QC, QC Recommendation, GEO, GEO Recommendation, Geo Supervisor, Geo Supervisor Recommendation]
# Index: []
#
# [0 rows x 54 columns]

# %%
file_name = files[0].split(' (')[0]
print(file_name+'.xlsx')
# combined_df.to_excel(file_name+'.xlsx', index=False)
combined_df.to_excel(dir+'/Geo Data 03 Mar 2026.xlsx', index=False)
# Out:
# C:\Users\Aaltoum\Desktop\Excels\GeoData\GEO DATA/Geo1.xlsx.xlsx

# %%
# combined_df = load_excel(r"\\10.150.40.49\las\Anas Alhares\NewTeam\E and C Final Folder 08092024\Case Editing and Classification\Editor Team\07-Raw Data\03-PBI Data\Geo data\Geo 2025-2026 (27-1-2026) 2.xlsx")
nov=combined_df[combined_df["Transferred to Geospatial"]<='2025-12-']
# nov=df[df["Transferred to Geospatial"]<='2025-12-04']
print(len(nov))
# nov.to_excel(f"{file_name} - Nov.xlsx", index=False)
nov.head(5)
# Out:
# 1563
#        Case Number Absolute Ownership  Duplicate Case  Generated Titles  \
# 69   FR20251000615                NaN             0.0               0.0
# 109  FR20251000972                NaN             0.0               0.0
# 113  FR20251001009                NaN             0.0               0.0
# 201  FR20251002035                NaN             0.0               0.0
# 771  FR20251006785                NaN             0.0               0.0
#
#     Case Submission Date      Latest Action Date                  Action  \
# 69   2025-11-23 18:56:29 2026-01-06 19:30:21.493     Geo Supervisor Pool
# 109  2025-11-23 19:48:07 2025-12-08 08:08:59.020                Geo Pool
# 113  2025-11-23 19:52:20 2025-12-08 08:06:58.480                Geo Pool
# 201  2025-11-23 22:02:31 2026-01-08 09:07:35.657     Geo Supervisor Pool
# 771  2025-11-24 18:22:22 2026-01-28 22:41:02.133  Geo Supervisor Claimed
#
#           Assignee Transferred to Geospatial Return To Geo Team  ...  \
# 69             NaN   2025-12-07 12:48:44.307                 No  ...
# 109            NaN   2025-12-08 08:09:14.947                 No  ...
# 113            NaN   2025-12-08 08:07:16.347                 No  ...
# 201            NaN   2025-12-09 19:50:14.690                Yes  ...
# 771  Obada AlMousa   2025-12-08 23:28:50.727                Yes  ...
#
#                     CW                                  CW Recommendation  \
# 69       Bushra Alamri  assignGeospatial | مساحة واطوال العقار خارج ال...
# 109     Riyadh Alsaeed                               assignGeospatial | .
# 113     Riyadh Alsaeed                               assignGeospatial | .
# 201    Khalid Alghamdi  assignGeospatial | " التعديل لتسجيل العقار وفق...
# 771  Maryam Alshamrany  assignGeospatial | كرما عكس حدود العقار مرفق ا...
#
#      CWS  CWS Recommendation   QC  QC Recommendation                GEO  \
# 69   NaN                 NaN  NaN                NaN  Mahmoud aboelmagd
# 109  NaN                 NaN  NaN                NaN                NaN
# 113  NaN                 NaN  NaN                NaN                NaN
# 201  NaN                 NaN  NaN                NaN     Lamya Mohammed
# 771  NaN                 NaN  NaN                NaN     Lamya Mohammed
#
#      GEO Recommendation    Geo Supervisor  \
# 69             submit |               NaN
# 109                 NaN               NaN
# 113                 NaN               NaN
# 201            submit |    Moataz Ibrahim
# 771            submit |  Abdullah Zamzami
#
#                          Geo Supervisor Recommendation
# 69                                                 NaN
# 109                                                NaN
# 113                                                NaN
# 201  submit | يعاد الى مدقق الطلبات-نقص في المستندا...
# 771  submit | يعاد إلى مدقق الطلبات‑نقص في المستندا...
#
# [5 rows x 54 columns]

# %%
nov[(nov["Transferred to Geospatial"] >= '2025-12-01') & (nov["Transferred to Geospatial"] <= '2025-12-02')].to_excel(f"{file_name} - 1 Dec.xlsx", index=False)

# %%
nov["Transferred to Geospatial"].max()
# Out:
# Timestamp('2025-12-03 23:30:15.240000')

# %% [markdown]
# ### Update GeoCompletion For Evaluation

# %%
# engine_postgres2 = create_engine("postgresql://postgres:1234@localhost:5432/GRS")
# last_update_post = pd.read_sql("SELECT MAX(\"UploadDate\") FROM public.\"GeoCompletion\" ", engine_postgres2).iloc[0,0]
last_update_sql = pd.read_sql("SELECT MAX(\"UploadDate\") FROM grsdbrd.\"GeoSCompletionData\" ", engine_sqlserver).iloc[0,0]
last_update_comp = pd.read_sql("SELECT MAX(\"UploadDate\") FROM grsdbrd.\"GeoCompletion\" ", engine_sqlserver).iloc[0,0]
print(last_update_sql,last_update_comp)
# Out:
# 2026-03-04 2026-03-03

# %%
# geocomp = pd.read_sql(f"""SELECT * FROM grsdbrd."GeoSCompletionData" 
#                        WHERE "UploadDate" BETWEEN '2026-02-15' AND '2026-03-02' """, engine_sqlserver)
# # print(len(geocomp))
# # geocomp.head()

# %%
geocomp = pd.read_sql(f"""SELECT * FROM grsdbrd."GeoSCompletionData" 
                       WHERE "UploadDate"> '{last_update_comp}' """, engine_sqlserver)
working_dates = pd.read_sql("""SELECT DISTINCT("GEO S Completion") FROM grsdbrd."GeoSCompletionData" 
                            UNION
                            SELECT DISTINCT("GEO S Completion") FROM grsdbrd."HistoricalData" """, engine_sqlserver)
working_dates = convert_to_date(working_dates)['GEO S Completion'].unique().tolist()
print(len(geocomp))
geocomp = convert_to_date(geocomp)
# geocomp["UploadDate"].unique()
# Out:
# 2979

# %%
completed = geocomp.copy()
completed = getGeoAction(completed)
completed['SLA'] = completed[["Transferred to Geospatial", "GEO S Completion"]].apply(lambda row: calculate_sla(row, working_dates), axis=1)
# # completed
# Out:
# C:\Users\Aaltoum\AppData\Local\Temp\ipykernel_23656\2522329259.py:96: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   trans_date = row[0]
# C:\Users\Aaltoum\AppData\Local\Temp\ipykernel_23656\2522329259.py:97: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   comp_date = row[1]

# %%
# completed[completed.columns[-10:]].head()
completed["UploadDate"].unique()
# Out:
# array(['2026-03-04'], dtype=object)

# %%
# comp_data = pd.read_sql(f"""SELECT * FROM grsdbrd."GeoCompletion" WHERE "UploadDate" BETWEEN '2026-02-15' AND '2026-03-02' """, engine_sqlserver)
# print(len(comp_data))

# %%
# merged = pd.merge(comp_data[["Case Number", "UniqueKey", "Geo Supervisor Recommendation", "GeoAction", "Rejection"]],
#                   completed[["Case Number", "UniqueKey", "Geo Supervisor Recommendation", "GeoAction", "Rejection"]], on="UniqueKey", how='inner')
# print(len(merged))

# %%
# completed[(completed["GeoAction"]=='رفض') & (completed["Geo Supervisor Recommendation"].str.contains('تم'))][["Geo Supervisor Recommendation", "GeoAction", "Rejection"]].to_excel(
#     r"C:\Users\Aaltoum\Desktop\Excels\GeoData\Test Actions.xlsx", index=False)

# %%
# merged[merged["GeoAction_x"]!=merged["GeoAction_y"]]
# # merged[["GeoAction_x", "GeoAction_y"]]

# %%
editorlist = pd.read_sql("SELECT * FROM evaluation.\"EditorsList\" ", engine_postgres2)
editorlist = convert_to_date(editorlist)
editorlist = editorlist[["EditorName", "CasePortalName",  "UserID", "SupervisorID", "SupervisorName", "GroupID", "ListDate"]]
print(len(editorlist))
editorlist.head()
# Out:
# 285
#                   EditorName    CasePortalName         UserID  SupervisorID  \
# 0           Bander Al-Hilali   Bander AlHilali      Bhilali.c          None
# 1            Ahad Al-Zahrani    Ahad AlZahrani  ASAlZahrani.c  SAlfuraihi.c
# 2     Saleh Mansour Al-Morqi     Saleh AlMorqi     Salmorqi.c  SAlfuraihi.c
# 3          Latifa Al-Rasheed  Latifa AlRasheed   Lalrasheed.c  SAlfuraihi.c
# 4  Dyaeldin Mohamed Mahmoud   Dyaeldin Mahmoud     Dmahmoud.c  SAlfuraihi.c
#
#      SupervisorName               GroupID    ListDate
# 0              None       Subsequent Team  2026-02-15
# 1  Shaden Alfuraihi  Editor Morning Shift  2026-02-15
# 2  Shaden Alfuraihi  Editor Morning Shift  2026-02-15
# 3  Shaden Alfuraihi  Editor Morning Shift  2026-02-15
# 4  Shaden Alfuraihi  Editor Morning Shift  2026-02-15

# %%
# editorlist.to_excel(r"D:\Unclassified\Eng. Mutaz\Userlist\UserList_2026-02-08_final.xlsx", index=False)

# %%
comp = join_userlist(completed, editorlist)
comp[comp.columns[-15:]].head(3)
# Out:
#   Geo Supervisor       Geo Supervisor Recommendation  \
# 0  AHMED Mahmmod  submit | تم تعديل البيانات الوصفية
# 1  AHMED Mahmmod  submit | تم تعديل البيانات الوصفية
# 2  AHMED Mahmmod  submit | تم تعديل البيانات الوصفية
#
#                            UniqueKey  UploadDate UploadedBy   Region  \
# 0  FR20251194323_2026-03-03 21:52:14  2026-03-04    Aaltoum  Eastern
# 1  FR20251277783_2026-03-03 21:52:14  2026-03-04    Aaltoum  Eastern
# 2  FR20251284036_2026-03-03 21:58:19  2026-03-04    Aaltoum  Eastern
#
#             GeoAction Rejection  SLA                    EditorName  \
# 0  تعديل بيانات وصفية             62  AHMED Mustafa Mahmmod Alqadi
# 1  تعديل بيانات وصفية             55  AHMED Mustafa Mahmmod Alqadi
# 2  تعديل بيانات وصفية             50  AHMED Mustafa Mahmmod Alqadi
#
#        UserID SupervisorID SupervisorName             GroupID    ListDate
# 0  amahmmod.c   Amarzouk.c   Anas Marzouk  Editor Night Shift  2026-02-15
# 1  amahmmod.c   Amarzouk.c   Anas Marzouk  Editor Night Shift  2026-02-15
# 2  amahmmod.c   Amarzouk.c   Anas Marzouk  Editor Night Shift  2026-02-15

# %%
print(len(comp[comp["Region"].isna()])), print(len(comp[comp["UserID"].isna()]))
# Out:
# 0
# 3
# (None, None)

# %%
name1 = editorlist[editorlist["CasePortalName"]=="Norah Muteb"]["CasePortalName"].unique()
comp[comp["Case Number"]== "FR20251268950"]["Geo Supervisor"].unique()
# Out:
# array(['Norah Muteb'], dtype=object)

# %%
comp[(comp["UserID"].isna()) & (comp["Geo Supervisor"]!='Mohammed Alzeer')][["Case Number", "Geo Supervisor"]]
# Out:
# Empty DataFrame
# Columns: [Case Number, Geo Supervisor]
# Index: []

# %%
comp.to_sql("GeoCompletion", engine_sqlserver, schema='grsdbrd', if_exists="append", index=False)
# Out:
# -1

# %%
pod_df = pd.read_sql("""SELECT * FROM grsdbrd."GeoCompletion"
WHERE "GroupID" IN ('Pod-Al-Shuhada-1','Pod-Al-Shuhada-2')
AND [GEO S Completion] BETWEEN '2025-12-01' AND '2025-12-31'
-- GROUP BY [Geo Supervisor] """, engine_sqlserver)
pod_df = convert_to_date(pod_df)
len(pod_df)
# Out:
# 1143

# %%
# pod_df[["Case Number", "Transferred to Geospatial", "GEO S Completion", "Geo Supervisor", "Geo Supervisor Recommendation"]].to_excel(r"\\10.150.40.49\las\Mutaz\data\POD Cases - December2025.xlsx", index=False)

# %%
editors=editorlist.rename(columns={"CasePortalName": "CaseProtalName"})
editors.head()
# Out:
#                EditorName      CaseProtalName         UserID     SupervisorID  \
# 0          Nawaf Al-Harbi       Nawaf AlHarbi       Nharbi.c  MMohammedKhir.c
# 1      Ibrahim Abu Bashar  Ibrahim Abu Bashar      Ibashar.c      ralotaibi.c
# 2      Khaled Abdulwahab    Khaled Abdulwahab  Kabdulwahab.c          oazab.c
# 3            Othman Sager        Othman Sager       osager.c         obakri.c
# 4  Abbas Omar Mohamed Ali           Abbas Ali         aali.c        tmqasem.c
#
#        SupervisorName               GroupID    ListDate
# 0  Mazin MohammedKhir    Editor Night Shift  2025-12-28
# 1       Reem Alotaibi  Editor Morning Shift  2025-12-28
# 2           Omar Azab    Editor Night Shift  2025-12-28
# 3         Osman Bakri  Editor Morning Shift  2025-12-28
# 4                TAHA               QC Team  2025-12-28

# %%
editors2 = pd.read_sql("""SELECT MAX("ListDate") FROM grsdbrd."EditorsList" """, engine_sqlserver).iloc[0,0]
editors1 = pd.read_sql(f"""SELECT DISTINCT("ListDate") FROM public."EditorsList" 
                       WHERE "ListDate" > '2025-11-18' """, engine_postgres).iloc[0,0]
editors1
# Out:
# '2025-12-09'

# %%
editors.to_sql("EditorsList", engine_postgres, schema='public', if_exists='append', index=False)
# Out:
# 267

# %%
new_comp = convert_to_date(new_comp)
new_comp = getGeoAction(new_comp)
comp_combined = join_userlist(new_comp, editors)

# %%
def get_connection_Sql():
    return pyodbc.connect(
        f"DRIVER={{SQL Server}};"
        f"SERVER={AppDB_CONFIG['server']};"
        f"DATABASE={AppDB_CONFIG['database']};"
        f"UID={AppDB_CONFIG['username']};"
        f"PWD={AppDB_CONFIG['password']};"
    )

def fetch_finalstatus_counts():
    conn = get_connection_Sql()
    # conn=get_connection_liteanother()
    cursor = conn.cursor()
    cursor.execute("""SELECT "Case Number", "Case Submission Date", "Transferred to Geospatial", "FinalStatus", "Task_Classification" 
                   FROM RER_cases_PowerBI_sync WITH (NOLOCK)
                   WHERE FinalStatus <> 'Complete'""")
    results = cursor.fetchall()
    results = pd.DataFrame.from_records(results, columns=[column[0] for column in cursor.description])
    cursor.close()
    conn.close()
    return results  # List of tuples like [('Complete', 30), ...]

# %%
results = fetch_finalstatus_counts()
results
# Out:
#           Case Number Case Submission Date Transferred to Geospatial  \
# 0       FR20251037326  2025-11-30 11:20:44   2025-12-05 12:55:33.030
# 1        FR2025912464  2025-11-04 20:52:52   2025-12-28 12:19:47.173
# 2        FR2025913577  2025-11-05 08:25:17   2025-12-09 11:29:17.190
# 3        FR2025914016  2025-11-05 09:59:57   2025-12-04 08:58:54.143
# 4        FR2025915053  2025-11-05 12:47:07   2025-12-16 20:02:11.233
# ...               ...                  ...                       ...
# 141097  FR20251157677  2025-12-13 10:05:38   2025-12-24 16:42:04.843
# 141098  FR20251168965  2025-12-13 23:56:55   2025-12-24 15:30:19.647
# 141099  FR20251168977  2025-12-13 23:58:28   2025-12-25 03:55:22.323
# 141100  FR20251169048  2025-12-14 00:13:36   2025-12-24 19:02:45.763
# 141101  FR20251169052  2025-12-14 00:14:14   2025-12-25 04:02:50.393
#
#        FinalStatus Task_Classification
# 0              New   تعديل أبعاد الأرض
# 1              New                None
# 2              New                None
# 3              New              Others
# 4              New   تعديل أبعاد الأرض
# ...            ...                 ...
# 141097         New                None
# 141098         New                None
# 141099         New                None
# 141100         New                None
# 141101         New                None
#
# [141102 rows x 5 columns]

# %%
comp_combined[comp_combined.columns[-12:]]
# Out:
#                              UniqueKey  UploadDate  UploadedBy   Region  \
# 0     FR2025772929_2025-11-23 16:08:24  2025-11-24  MIbrahim.c   Riyadh
# 1     FR2025828003_2025-11-23 23:15:05  2025-11-24  MIbrahim.c  Eastern
# 2     FR2025832839_2025-11-23 17:54:55  2025-11-24  MIbrahim.c   Riyadh
# 3     FR2025858924_2025-11-23 17:05:57  2025-11-24  MIbrahim.c   Riyadh
# 4     FR2025893570_2025-11-23 19:55:06  2025-11-24  MIbrahim.c  Eastern
# ...                                ...         ...         ...      ...
# 3124  FR2025920222_2025-11-23 13:53:04  2025-11-24  MIbrahim.c    Qasim
# 3125  FR2025920548_2025-11-23 14:06:14  2025-11-24  MIbrahim.c    Qasim
# 3126  FR2025923144_2025-11-23 10:21:57  2025-11-24  MIbrahim.c    Makka
# 3127  FR2025927138_2025-11-23 09:02:13  2025-11-24  MIbrahim.c    Makka
# 3128  FR2025930512_2025-11-23 13:16:24  2025-11-24  MIbrahim.c  Madinah
#
#                GeoAction           Rejection                    EditorName  \
# 0                    رفض  محضر الدمج/التجزئة  AHMED Mustafa Mahmmod Alqadi
# 1     تعديل بيانات وصفية                      AHMED Mustafa Mahmmod Alqadi
# 2     تعديل بيانات وصفية                      AHMED Mustafa Mahmmod Alqadi
# 3                    دمج                      AHMED Mustafa Mahmmod Alqadi
# 4                    رفض         إختيار خاطئ  AHMED Mustafa Mahmmod Alqadi
# ...                  ...                 ...                           ...
# 3124                 رفض            صك الأرض                Wijdan Al-Asab
# 3125                 رفض            صك الأرض                Wijdan Al-Asab
# 3126               تجزئة                                    Wijdan Al-Asab
# 3127  تعديل بيانات وصفية                                    Wijdan Al-Asab
# 3128                 رفض            صك الأرض                Wijdan Al-Asab
#
#           UserID  SupervisorID           SupervisorName               GroupID  \
# 0     amahmmod.c      MFadil.c  Mohammed Abdallah Fadil    Editor Night Shift
# 1     amahmmod.c      MFadil.c  Mohammed Abdallah Fadil    Editor Night Shift
# 2     amahmmod.c      MFadil.c  Mohammed Abdallah Fadil    Editor Night Shift
# 3     amahmmod.c      MFadil.c  Mohammed Abdallah Fadil    Editor Night Shift
# 4     amahmmod.c      MFadil.c  Mohammed Abdallah Fadil    Editor Night Shift
# ...          ...           ...                      ...                   ...
# 3124     Wasab.c  SAlfuraihi.c         Shden Al-Furaihi  Editor Morning Shift
# 3125     Wasab.c  SAlfuraihi.c         Shden Al-Furaihi  Editor Morning Shift
# 3126     Wasab.c  SAlfuraihi.c         Shden Al-Furaihi  Editor Morning Shift
# 3127     Wasab.c  SAlfuraihi.c         Shden Al-Furaihi  Editor Morning Shift
# 3128     Wasab.c  SAlfuraihi.c         Shden Al-Furaihi  Editor Morning Shift
#
#         ListDate
# 0     2025-11-18
# 1     2025-11-18
# 2     2025-11-18
# 3     2025-11-18
# 4     2025-11-18
# ...          ...
# 3124  2025-11-18
# 3125  2025-11-18
# 3126  2025-11-18
# 3127  2025-11-18
# 3128  2025-11-18
#
# [3129 rows x 12 columns]

# %%
engine_postgres2
# Out:
# Engine(postgresql://postgres:***@localhost:5432/GRS)

# %%
evaluation = pd.read_sql("""SELECT "EditorName", COUNT("Case Number") AS "Count OF Cases" FROM evaluation."EvaluationTable" 
                         GROUP BY "EditorName" """, engine_postgres2)
evaluation.head()
# Out:
#         EditorName  Count OF Cases
# 0  Shurooq AlHarbi               4
# 1   Abdulaziz Faiz              10
# 2     Amr Alsanosy               8
# 3   Hisham Alshwei               6
# 4   Bayan AlGhamdi               7

# %%
evaluation.to_excel(r"D:\Unclassified\Eng. Anas\Evaluation Productivity - Breakdown by Editor.xlsx", index=False)

# %%
editorlist[editorlist["ListDate"]==editorlist["ListDate"].max()].to_sql("EditorsList", engine_postgres2, schema='evaluation', if_exists="replace", index=False)
# Out:
# 261

# %%
engine_postgres2 = create_engine("postgresql://postgres:1234@localhost:5432/GRS")

# %%
tables = pd.read_sql("""SELECT TABLE_NAME FROM INFORMATION_SCHEMA.TABLES WHERE TABLE_SCHEMA = 'evaluation'""", engine_postgres2)["table_name"].tolist()b
tables
# Out:
# ['EvaluationTable',
#  'CaseAssignment',
#  'Regions',
#  'SupervisorReplacements',
#  'Administrator',
#  'OpsData',
#  'EditorsList']

# %%
editorlist.to_excel(r"D:\Unclassified\DB Tables\Evaluation\EditorsList_all.xlsx", index=False)

# %%
for table in tables:
    df = pd.read_sql(f"""SELECT * FROM evaluation."{table}" """, engine_postgres2)
    df.to_excel(r"D:\Unclassified\DB Tables\Evaluation"+f"/{table}.xlsx", index=False)

# %% [markdown]
# ### Assign Cases to Supervisor:

# %%
active_editors = ['Ibrahim Abu Bashar', 'Khaled Abdulwahab', 'Othman Sager', 'Abdulaziz Alhegbani', 'Abdulaziz Faiz', 'Abdulbaqi Hamed', 'Abdullah AlHujailan', 
                  'Abdulmalik Alzahrani', 'Afnan Alhumaidy', 'Afnan Mohammed', 'Ahad AlZahrani', 'Ahmad Ishag', 'Ahmed Dafaaldeen', 'Ahmed Alghamdi', 'Alanood Alghamdi', 
                  'Alhanouf Almarzouq', 'Ali Nasser', 'Alsiddig Hassballa', 'Amal Altalhi', 'Amjad Alamri', 'Amr Alsanosy', 'Anwar Aljarallah', 'Aseel Hasnoon', 'Asmaa Alanazi', 
                  'Asaad Ali', 'Atiyaf AlJadani', 'Dyaeldin Mahmoud', 'Fahad AlRuwis', 'Fala Alharbi', 'Faris Alshibani', 'Fayez Khalfa', 'Ghufran AlJabri', 'Hamad Alrashidi', 
                  'Hany Mansour', 'Husaam Shaaban', 'Ibrahim Alghamdi', 'Ithar AlMudan', 'Jasser Aljasser', 'Jawaher AlSultan', 'Khaled AlSharif', 'Lamya Mohammed', 'Latifa AlRasheed', 
                  'Maha Alzahrani', 'Majed AlHassan', 'Mohamed Baday', 'Mohamed Hasabeldaeim', 'Mohammed Yousef Mohammed', 'Mohammad Ramdhan', 'Mohammed Akthum', 'Mohammed Alfathel', 
                  'Mohammed Badawi', 'Mohammed Alburayk', 'Mohammed alddin', 'Mohammed Hamed', 'Mohammed Sheikh', 'Mosaab Mohamed', 'Muhanad Mansur', 'Musab AlSheikh', 'Mustafa Hasab', 
                  'Muteb Altaher', 'Najah Almuteri', 'Najla Alotaibi', 'Nawaf Alrayyani', 'Nouf Albalawi', 'Noura AlDosari', 'Omar Azab', 'Omar Hamid', 'Omar Salah', 'Omer Mohammed', 
                  'Osama Mohamed', 'Osama Ali', 'Rahaf AlZaylai', 'Rakan Alzaila', 'Rana Alghufaili', 'Rana AlSheikh', 'Razan AlMuqayel', 'Refal Alharbi', 'Rehab Alghamdi', 'Renad Alkaak', 
                  'Rowa Alsadig', 'Safa Alnoor', 'Saleh AlMorqi', 'Samer Mohammed', 'Shurooq AlHarbi', 'Sultan Almutairi', 'Wadaa Alghamdi', 'Walaa Ali', 'Waleed Hassan', 'Wardah Alshahrani', 
                  'Abdulaziz Almutlaq', 'Abdulhafeez Mohammed', 'Abdullah AlMalki', 'Abdulrahman AlMubarak', 'Ammar Kamal', 'Suhaib AlSharif', 'Mohammed Mahgoub', 'Mohammed Mukhtar', 
                  'Musab AlAmin', 'Muslim Almjfel', 'Obada AlMousa']

# %%
supervisors = pd.read_sql("""SELECT DISTINCT("SupervisorName") FROM evaluation."EditorsList" 
                          WHERE "GroupID" IN ('Editor Morning Shift','Editor Night Shift','Pod-Al-Shuhada-1','Pod-Al-Shuhada-2','Urgent Team'
                ) """, engine_postgres2)["SupervisorName"].tolist()
supervisors
# Out:
# ['Osman Bakri',
#  'Mazin MohammedKhir',
#  'Mohammed Barakat',
#  'Mustafa Alnmar',
#  'Musab Hassan',
#  'Shaden Alfuraihi',
#  'Ahmad ElFadil',
#  'Reem Alotaibi',
#  'Mohammed Ibrahim Mohammed',
#  'Raseel Alharthi',
#  'Fatimah Almarshed',
#  'Mohammed Mustafa Al-Daly',
#  'Mohammed Fadil',
#  'Fatimah Haddadi']

# %%
supervisors.remove('Mohammed Mustafa Al-Daly')
supervisors.remove('Musab Hassan')
supervisors
# Out:
# ['Osman Bakri',
#  'Mazin MohammedKhir',
#  'Mohammed Barakat',
#  'Mustafa Alnmar',
#  'Shaden Alfuraihi',
#  'Ahmad ElFadil',
#  'Reem Alotaibi',
#  'Mohammed Ibrahim Mohammed',
#  'Raseel Alharthi',
#  'Fatimah Almarshed',
#  'Mohammed Fadil',
#  'Fatimah Haddadi']

# %%
len(supervisors)
# Out:
# 12

# %%
cases = pd.read_sql(f"""SELECT *
        FROM evaluation."OpsData"
        WHERE "GeoAction" <> 'No Action'
        -- AND "GroupID" IN ('Editor Morning Shift','Editor Night Shift','Pod-Al-Shuhada-1','Pod-Al-Shuhada-2','Urgent Team')
        AND "Geo Supervisor" IN ({str(active_editors).strip('[]')})         
        AND "UniqueKey" NOT IN (
            SELECT "UniqueKey" FROM evaluation."EvaluationTable"
            UNION
            SELECT "UniqueKey" FROM evaluation."CaseAssignment"
        )
        -- AND "GEO S Completion" >= CURRENT_DATE - INTERVAL '180 days'
        """, engine_postgres2)
cases = cases.sort_values(by="GEO S Completion", ascending=False)
cases.head()
# Out:
#     Case Number Absolute Ownership  Duplicate Case  Generated Titles  \
# 0  FR2025101945               None             0.0               0.0
#
#   Case Submission Date Latest Action Date   Action Assignee  \
# 0           2025-08-26         2025-12-16  CW Pool     None
#
#   Transferred to Geospatial Return To Geo Team  ...  UploadedBy Region  \
# 0                2025-11-05                Yes  ...  MIbrahim.c  Qasim
#
#   GeoAction Rejection       EditorName        UserID  SupervisorID  \
# 0       دمج            Mohamed Youssef  MYMohammed.c     mhassan.c
#
#    SupervisorName         GroupID    ListDate
# 0    Musab Hassan  Urgent Team -1  2025-11-04
#
# [1 rows x 66 columns]

# %%
for i in active_editors:
   case = cases[cases["Geo Supervisor"]==i]
   if len(case) > 0:
      print(i, f"has {len(case)} cases")
# Out:
# Mohammed Yousef Mohammed has 1 cases

# %%
# ===============================
# ASSIGNMENT LOGIC
# ===============================
assignments = []
supervisor_index = 0
for editor in active_editors:
    editor_cases = cases[cases["Geo Supervisor"] == editor]
    print(f"Processing editor: {editor} with {len(editor_cases)} cases")

    reject_cases = editor_cases[editor_cases["GeoAction"] == "رفض"]
    edit_cases   = editor_cases[editor_cases["GeoAction"] != "رفض"]

    # Search back if missing category
    if reject_cases.empty or edit_cases.empty:
        for d in range(1, 180 + 1):
            target_date = datetime.now().date() - timedelta(days=d)

            df_more = cases[
                (cases["Geo Supervisor"] == editor) &
                (cases["GEO S Completion"] == target_date)
            ]

            if reject_cases.empty:
                reject_cases = df_more[df_more["GeoAction"] == "رفض"]

            if edit_cases.empty:
                edit_cases = df_more[df_more["GeoAction"] != "رفض"]

            if not reject_cases.empty and not edit_cases.empty:
                break

    selected = []

    if not reject_cases.empty:
        selected.append(reject_cases.sample(1))

    if not edit_cases.empty:
        selected.append(edit_cases.sample(1))

    if not selected:
        continue

    for row_df in selected:
        row = row_df.iloc[0].to_dict()
        assigned_supervisor = supervisors[supervisor_index % len(supervisors)]
        supervisor_index += 1

        assignments.append({
            "UniqueKey": row["UniqueKey"],
            "Case Number": row["Case Number"],
            "REN": row["REN"],
            "CompletionDate": row["GEO S Completion"],
            "EditorName": row["Geo Supervisor"],
            "EditorRecommendation": row["Geo Supervisor Recommendation"],
            "SupervisorName": row["SupervisorName"],
            "GroupID": row["GroupID"],
            "GeoAction": row["GeoAction"],
            "Region": row["Region"],
            "AssignedSupervisor": assigned_supervisor,
            "AssignmentDate": datetime.now().date()
        })
# Out:
# Processing editor: Ibrahim Abu Bashar with 0 cases
# Processing editor: Khaled Abdulwahab with 0 cases
# Processing editor: Othman Sager with 0 cases
# Processing editor: Abdulaziz Alhegbani with 0 cases
# Processing editor: Abdulaziz Faiz with 0 cases
# Processing editor: Abdulbaqi Hamed with 0 cases
# Processing editor: Abdullah AlHujailan with 0 cases
# Processing editor: Abdulmalik Alzahrani with 0 cases
# Processing editor: Afnan Alhumaidy with 0 cases
# Processing editor: Afnan Mohammed with 0 cases
# Processing editor: Ahad AlZahrani with 0 cases
# Processing editor: Ahmad Ishag with 0 cases
# Processing editor: Ahmed Dafaaldeen with 0 cases
# Processing editor: Ahmed Alghamdi with 0 cases
# Processing editor: Alanood Alghamdi with 0 cases
# Processing editor: Alhanouf Almarzouq with 0 cases
# Processing editor: Ali Nasser with 0 cases
# Processing editor: Alsiddig Hassballa with 0 cases
# Processing editor: Amal Altalhi with 0 cases
# Processing editor: Amjad Alamri with 0 cases
# Processing editor: Amr Alsanosy with 0 cases
# Processing editor: Anwar Aljarallah with 0 cases
# Processing editor: Aseel Hasnoon with 0 cases
# Processing editor: Asmaa Alanazi with 0 cases
# Processing editor: Asaad Ali with 0 cases
# Processing editor: Atiyaf AlJadani with 0 cases
# Processing editor: Dyaeldin Mahmoud with 0 cases
# Processing editor: Fahad AlRuwis with 0 cases
# Processing editor: Fala Alharbi with 0 cases
# Processing editor: Faris Alshibani with 0 cases
# Processing editor: Fayez Khalfa with 0 cases
# Processing editor: Ghufran AlJabri with 0 cases
# Processing editor: Hamad Alrashidi with 0 cases
# Processing editor: Hany Mansour with 0 cases
# Processing editor: Husaam Shaaban with 0 cases
# Processing editor: Ibrahim Alghamdi with 0 cases
# Processing editor: Ithar AlMudan with 0 cases
# Processing editor: Jasser Aljasser with 0 cases
# Processing editor: Jawaher AlSultan with 0 cases
# Processing editor: Khaled AlSharif with 0 cases
# Processing editor: Lamya Mohammed with 0 cases
# Processing editor: Latifa AlRasheed with 0 cases
# Processing editor: Maha Alzahrani with 0 cases
# Processing editor: Majed AlHassan with 0 cases
# Processing editor: Mohamed Baday with 0 cases
# Processing editor: Mohamed Hasabeldaeim with 0 cases
# Processing editor: Mohammed Yousef Mohammed with 1 cases
# Processing editor: Mohammad Ramdhan with 0 cases
# Processing editor: Mohammed Akthum with 0 cases
# Processing editor: Mohammed Alfathel with 0 cases
# Processing editor: Mohammed Badawi with 0 cases
# Processing editor: Mohammed Alburayk with 0 cases
# Processing editor: Mohammed alddin with 0 cases
# Processing editor: Mohammed Hamed with 0 cases
# Processing editor: Mohammed Sheikh with 0 cases
# Processing editor: Mosaab Mohamed with 0 cases
# Processing editor: Muhanad Mansur with 0 cases
# Processing editor: Musab AlSheikh with 0 cases
# Processing editor: Mustafa Hasab with 0 cases
# Processing editor: Muteb Altaher with 0 cases
# Processing editor: Najah Almuteri with 0 cases
# Processing editor: Najla Alotaibi with 0 cases
# Processing editor: Nawaf Alrayyani with 0 cases
# Processing editor: Nouf Albalawi with 0 cases
# Processing editor: Noura AlDosari with 0 cases
# Processing editor: Omar Azab with 0 cases
# Processing editor: Omar Hamid with 0 cases
# Processing editor: Omar Salah with 0 cases
# Processing editor: Omer Mohammed with 0 cases
# Processing editor: Osama Mohamed with 0 cases
# Processing editor: Osama Ali with 0 cases
# Processing editor: Rahaf AlZaylai with 0 cases
# Processing editor: Rakan Alzaila with 0 cases
# Processing editor: Rana Alghufaili with 0 cases
# Processing editor: Rana AlSheikh with 0 cases
# Processing editor: Razan AlMuqayel with 0 cases
# Processing editor: Refal Alharbi with 0 cases
# Processing editor: Rehab Alghamdi with 0 cases
# Processing editor: Renad Alkaak with 0 cases
# Processing editor: Rowa Alsadig with 0 cases
# Processing editor: Safa Alnoor with 0 cases
# Processing editor: Saleh AlMorqi with 0 cases
# Processing editor: Samer Mohammed with 0 cases
# Processing editor: Shurooq AlHarbi with 0 cases
# Processing editor: Sultan Almutairi with 0 cases
# Processing editor: Wadaa Alghamdi with 0 cases
# Processing editor: Walaa Ali with 0 cases
# Processing editor: Waleed Hassan with 0 cases
# Processing editor: Wardah Alshahrani with 0 cases
# Processing editor: Abdulaziz Almutlaq with 0 cases
# Processing editor: Abdulhafeez Mohammed with 0 cases
# Processing editor: Abdullah AlMalki with 0 cases
# Processing editor: Abdulrahman AlMubarak with 0 cases
# Processing editor: Ammar Kamal with 0 cases
# Processing editor: Suhaib AlSharif with 0 cases
# Processing editor: Mohammed Mahgoub with 0 cases
# Processing editor: Mohammed Mukhtar with 0 cases
# Processing editor: Musab AlAmin with 0 cases
# Processing editor: Muslim Almjfel with 0 cases
# Processing editor: Obada AlMousa with 0 cases

# %%
assign_df = pd.DataFrame(assignments)
assign_df.head()
# assign_df.groupby("EditorName").size()
# assign_df
# Out:
#                           UniqueKey   Case Number               REN  \
# 0  FR2025101945_2025-11-06 11:48:35  FR2025101945  5877986446100000
#
#   CompletionDate                EditorName  \
# 0     2025-11-06  Mohammed Yousef Mohammed
#
#                                 EditorRecommendation SupervisorName  \
# 0  submit | يعاد الى مدقق الطلبات – نقص مستندات –...   Musab Hassan
#
#           GroupID GeoAction Region AssignedSupervisor AssignmentDate
# 0  Urgent Team -1       دمج  Qasim        Osman Bakri     2025-12-21

# %% [markdown]
# ### Case Count (Overtime Vs Normal hours)

# %%
period = 7
end_date = datetime.now().date() - timedelta(days=3)
start_date = end_date - timedelta(days=period)
geo_Comp = pd.read_sql(f"""SELECT * FROM grsdbrd.[GeoCompletion] WHERE [GEO S Completion] BETWEEN '{start_date}' AND '{end_date}' """, engine_sqlserver)

# %%
geo_Comp = convert_to_date(geo_Comp)

# %%
geo_Comp["CompletionTime"] = [pd.to_datetime(i.split('_')[1]) for i in geo_Comp["UniqueKey"]]
prod_df = geo_Comp[["Case Number", "Transferred to Geospatial", "GEO S Completion", "Geo Supervisor", "SupervisorName", "GroupID", "Region", "GeoAction", "Rejection", "CompletionTime"]]

# %%
# prod_df = geo_Comp[["Case Number", "Transferred to Geospatial", "GEO S Completion", "Geo Supervisor", "SupervisorName", "GroupID", "Region", "GeoAction", "Rejection", "CompletionTime"]]

# %%
# test = prod_df.copy()
prod_df["CompletionDate"] = prod_df["GEO S Completion"]
prod_df["GEO S Completion"] = prod_df.apply(
    lambda row: row['GEO S Completion'] - timedelta(days=1) 
    if row['CompletionTime'].time() < pd.to_datetime('04:30:00').time() 
    else row['GEO S Completion'], 
    axis=1
)
prod_df[prod_df['CompletionTime'].dt.time < pd.to_datetime('04:30:00').time()]
# Out:
# C:\Users\Aaltoum\AppData\Local\Temp\ipykernel_25192\894822032.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod_df["CompletionDate"] = prod_df["GEO S Completion"]
# C:\Users\Aaltoum\AppData\Local\Temp\ipykernel_25192\894822032.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod_df["GEO S Completion"] = prod_df.apply(
#          Case Number Transferred to Geospatial GEO S Completion  \
# 371    FR20251041604                2025-12-01       2026-01-12
# 372    FR20251041853                2025-12-01       2026-01-12
# 404    FR20251036520                2025-12-01       2026-01-12
# 405    FR20251036962                2025-12-05       2026-01-12
# 2890    FR2025921299                2025-11-25       2026-01-12
# ...              ...                       ...              ...
# 19650   FR2025979345                2025-12-08       2026-01-14
# 19672  FR20251123913                2025-12-11       2026-01-14
# 19673  FR20251155381                2025-12-16       2026-01-14
# 19674  FR20251135353                2025-12-15       2026-01-14
# 19675  FR20251154515                2025-12-16       2026-01-14
#
#        Geo Supervisor  SupervisorName             GroupID   Region  \
# 371    Omar Albuhayji  Musab AlSheikh  Editor Night Shift    Qasim
# 372    Omar Albuhayji  Musab AlSheikh  Editor Night Shift    Qasim
# 404    Omar Albuhayji  Musab AlSheikh  Editor Night Shift     Hael
# 405    Omar Albuhayji  Musab AlSheikh  Editor Night Shift  Eastern
# 2890   Mohammed Hamed  Musab AlSheikh  Support Team_Night    Qasim
# ...               ...             ...                 ...      ...
# 19650   Osama Mohamed  Musab AlSheikh  Editor Night Shift   Riyadh
# 19672     Safa Alnoor    Anas Marzouk  Editor Night Shift   Riyadh
# 19673     Safa Alnoor    Anas Marzouk  Editor Night Shift   Riyadh
# 19674     Safa Gobarh    Anas Marzouk  Editor Night Shift  Madinah
# 19675     Safa Gobarh    Anas Marzouk  Editor Night Shift   Riyadh
#
#                         GeoAction         Rejection      CompletionTime  \
# 371                           رفض          صك الأرض 2026-01-13 01:35:07
# 372                           رفض          صك الأرض 2026-01-13 01:38:37
# 404                           رفض          صك الأرض 2026-01-13 01:24:16
# 405                           رفض  طلب لوحدة عقارية 2026-01-13 01:47:47
# 2890   البيانات الجيومكانية صحيحة                   2026-01-13 01:02:33
# ...                           ...               ...                 ...
# 19650                       تجزئة                   2026-01-15 02:17:46
# 19672                         رفض          صك الأرض 2026-01-15 00:00:17
# 19673                         رفض          صك الأرض 2026-01-15 00:18:55
# 19674                         رفض          صك الأرض 2026-01-15 00:18:55
# 19675                         رفض          صك الأرض 2026-01-15 00:18:55
#
#       CompletionDate
# 371       2026-01-13
# 372       2026-01-13
# 404       2026-01-13
# 405       2026-01-13
# 2890      2026-01-13
# ...              ...
# 19650     2026-01-15
# 19672     2026-01-15
# 19673     2026-01-15
# 19674     2026-01-15
# 19675     2026-01-15
#
# [425 rows x 11 columns]

# %%
# Out:
# C:\Users\Aaltoum\AppData\Local\Temp\ipykernel_25192\281883288.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   prod_df['CompletionTime'] = prod_df.apply(

# %%
from datetime import time
# Extract cases by time period per editor per day
# mask_over = prod_df['CompletionTime'].dt.hour.between(0, 7)
# mask_normal = test['CompletionTime'].dt.hour.between(8, 23)
mask_over = prod_df['CompletionTime'].dt.time < time(8, 15)
mask_normal = prod_df['CompletionTime'].dt.time >= time(8, 15)
# mask_15_21 = prod_df['CompletionTime'].dt.hour.between(15, 20)
# mask_21_23 = prod_df['CompletionTime'].dt.hour.between(21, 23)

# Group by date and supervisor for each time period
# overtime = prod_df.loc[mask_over].groupby(['GEO S Completion', 'Geo Supervisor', 'SupervisorName', 'GroupID'])['Case Number'].nunique().reset_index(name='OverTime')
# normalhrs = prod_df.loc[mask_normal].groupby(['GEO S Completion', 'Geo Supervisor', 'SupervisorName', 'GroupID'])['Case Number'].nunique().reset_index(name='Normal')
# # time_15_21 = prod_df.loc[mask_15_21].groupby(['GEO S Completion', 'Geo Supervisor', 'SupervisorName', 'GroupID'])['Case Number'].nunique().reset_index(name='3-9PM')
# # time_21_23 = prod_df.loc[mask_21_23].groupby(['GEO S Completion', 'Geo Supervisor', 'SupervisorName', 'GroupID'])['Case Number'].nunique().reset_index(name='9-11PM')

# # Merge all time periods
# result_df = overtime.merge(normalhrs, on=['GEO S Completion', 'Geo Supervisor', 'SupervisorName', 'GroupID'], how='outer')
# # result_df = result_df.merge(time_15_21, on=['GEO S Completion', 'Geo Supervisor', 'SupervisorName', 'GroupID'], how='outer')
# # result_df = result_df.merge(time_21_23, on=['GEO S Completion', 'Geo Supervisor', 'SupervisorName', 'GroupID'], how='outer')

# # Add total column
# result_df['Total'] = result_df[['OverTime', 'Normal']].fillna(0).sum(axis=1).astype(int)#, '3-9PM', '9-11PM']].fillna(0).sum(axis=1).astype(int)

# # result_df = result_df.fillna(0).astype({col: int for col in ['7-9AM', '9-3PM', '3-9PM', '9-11PM']})
# result_df = result_df.sort_values(['GEO S Completion', 'Geo Supervisor'])

# result_df.head(20)

# %%
overtime = (prod_df.loc[mask_over].groupby(['GEO S Completion','Geo Supervisor', 'SupervisorName', 'GroupID'])
    .agg(
        OverTime=('Case Number', 'nunique'),
        Over_Start=('CompletionTime', 'min'),
        Over_End=('CompletionTime', 'max')
    ).reset_index())
normalhrs = (prod_df.loc[mask_normal].groupby(['GEO S Completion','Geo Supervisor', 'SupervisorName', 'GroupID'])
    .agg(
        Normal=('Case Number', 'nunique'),
        Normal_Start=('CompletionTime', 'min'),
        Normal_End=('CompletionTime', 'max')
    ).reset_index())

result_df = overtime.merge(normalhrs, on=['GEO S Completion','Geo Supervisor', 'SupervisorName', 'GroupID'],how='outer')

result_df['Total'] = (result_df[['OverTime', 'Normal']].fillna(0).sum(axis=1).astype(int)
)

result_df = result_df.sort_values(['Geo Supervisor', 'GEO S Completion'])

# %%
# result_df[(~result_df["OverTime"].isna()) & (result_df["Over_Start"]<pd.to_datetime('2026-01-12 7:30:00'))]
result_df
# Out:
#     GEO S Completion      Geo Supervisor     SupervisorName  \
# 95        2026-01-11       AHMED Mahmmod       Anas Marzouk
# 269       2026-01-12       AHMED Mahmmod       Anas Marzouk
# 444       2026-01-13       AHMED Mahmmod       Anas Marzouk
# 609       2026-01-14       AHMED Mahmmod       Anas Marzouk
# 96        2026-01-11  Abdulaziz AlOtaibi  Khaled Abdulwahab
# ..               ...                 ...                ...
# 94        2026-01-08       Wijdan AlAsab   Shaden Alfuraihi
# 268       2026-01-11       Wijdan AlAsab        Osman Bakri
# 443       2026-01-12       Wijdan AlAsab        Osman Bakri
# 608       2026-01-13       Wijdan AlAsab        Osman Bakri
# 774       2026-01-14       Wijdan AlAsab        Osman Bakri
#
#                   GroupID  OverTime          Over_Start            Over_End  \
# 95     Editor Night Shift       5.0 2026-01-12 00:08:45 2026-01-12 00:50:15
# 269    Editor Night Shift       5.0 2026-01-13 00:10:09 2026-01-13 00:48:16
# 444    Editor Night Shift       NaN                 NaT                 NaT
# 609    Editor Night Shift       NaN                 NaT                 NaT
# 96     Editor Night Shift       3.0 2026-01-12 00:15:31 2026-01-12 00:33:39
# ..                    ...       ...                 ...                 ...
# 94   Editor Morning Shift       NaN                 NaT                 NaT
# 268  Editor Morning Shift       NaN                 NaT                 NaT
# 443  Editor Morning Shift       NaN                 NaT                 NaT
# 608  Editor Morning Shift       NaN                 NaT                 NaT
# 774  Editor Morning Shift       NaN                 NaT                 NaT
#
#      Normal        Normal_Start          Normal_End  Total
# 95     29.0 2026-01-11 18:20:08 2026-01-11 23:58:18     34
# 269    30.0 2026-01-12 17:08:26 2026-01-12 23:57:08     35
# 444    33.0 2026-01-13 17:22:43 2026-01-13 23:28:47     33
# 609    31.0 2026-01-14 17:25:46 2026-01-14 23:52:45     31
# 96     26.0 2026-01-11 17:04:01 2026-01-11 23:59:55     29
# ..      ...                 ...                 ...    ...
# 94     14.0 2026-01-08 08:53:25 2026-01-08 11:24:05     14
# 268    29.0 2026-01-11 10:21:34 2026-01-11 15:45:30     29
# 443    30.0 2026-01-12 08:51:47 2026-01-12 15:40:56     30
# 608    24.0 2026-01-13 08:56:42 2026-01-13 15:57:30     24
# 774    30.0 2026-01-14 09:25:27 2026-01-14 15:05:47     30
#
# [775 rows x 11 columns]

# %%
result_df.to_excel(r"D:\Unclassified\Eng. Mashael\Overtime Vs Normal hours\Overtime 2026-01-11_15.xlsx", index=False)

# %%
editor = 'Akram Elkhidir'
overtime[overtime["Geo Supervisor"]==editor]
# Out:
#    GEO S Completion  Geo Supervisor SupervisorName             GroupID  \
# 11       2026-01-12  Akram Elkhidir   Anas Marzouk  Editor Night Shift
#
#     OverTime          Over_Start            Over_End
# 11         6 2026-01-12 00:08:45 2026-01-12 00:38:15

# %%
date = '2026-01-12'
prod_df[(prod_df["Geo Supervisor"]==editor) & (prod_df["GEO S Completion"]>=pd.to_datetime(date+ " 6:00:00").date())& (prod_df["CompletionTime"]<=pd.to_datetime(date+" 8:10:00"))].sort_values(by="CompletionTime")
# Out:
#       Case Number Transferred to Geospatial GEO S Completion  Geo Supervisor  \
# 32  FR20251032185                2025-11-30       2026-01-12  Akram Elkhidir
# 35   FR2025919513                2026-01-06       2026-01-12  Akram Elkhidir
# 34   FR2025919358                2026-01-06       2026-01-12  Akram Elkhidir
# 33  FR20251039929                2025-12-01       2026-01-12  Akram Elkhidir
# 36   FR2025937260                2025-12-03       2026-01-12  Akram Elkhidir
# 31  FR20251003476                2025-12-09       2026-01-12  Akram Elkhidir
#
#    SupervisorName             GroupID   Region  GeoAction         Rejection  \
# 32   Anas Marzouk  Editor Night Shift  Eastern      تجزئة
# 35   Anas Marzouk  Editor Night Shift  Eastern  No Action
# 34   Anas Marzouk  Editor Night Shift  Eastern  No Action
# 33   Anas Marzouk  Editor Night Shift   Riyadh  No Action
# 36   Anas Marzouk  Editor Night Shift   Riyadh        رفض    المخطط المعتمد
# 31   Anas Marzouk  Editor Night Shift   Riyadh        رفض  طلب لوحدة عقارية
#
#         CompletionTime
# 32 2026-01-12 00:08:45
# 35 2026-01-12 00:09:55
# 34 2026-01-12 00:13:47
# 33 2026-01-12 00:26:02
# 36 2026-01-12 00:33:39
# 31 2026-01-12 00:38:15

# %%
date = '2026-01-12'
prod_df[(prod_df["Geo Supervisor"]==editor) & (prod_df["GEO S Completion"]>=pd.to_datetime(date+" 00:00:00").date())& (prod_df["CompletionTime"]<=pd.to_datetime(date+" 9:00:00"))].sort_values(by="CompletionTime")
# Out:
#         Case Number Transferred to Geospatial GEO S Completion  \
# 4235  FR20251032185                2025-11-30       2026-01-12
# 4238   FR2025919513                2026-01-06       2026-01-12
# 4237   FR2025919358                2026-01-06       2026-01-12
# 4236  FR20251039929                2025-12-01       2026-01-12
# 4239   FR2025937260                2025-12-03       2026-01-12
# 4234  FR20251003476                2025-12-09       2026-01-12
#
#       Geo Supervisor SupervisorName             GroupID   Region  GeoAction  \
# 4235  Akram Elkhidir   Anas Marzouk  Editor Night Shift  Eastern      تجزئة
# 4238  Akram Elkhidir   Anas Marzouk  Editor Night Shift  Eastern  No Action
# 4237  Akram Elkhidir   Anas Marzouk  Editor Night Shift  Eastern  No Action
# 4236  Akram Elkhidir   Anas Marzouk  Editor Night Shift   Riyadh  No Action
# 4239  Akram Elkhidir   Anas Marzouk  Editor Night Shift   Riyadh        رفض
# 4234  Akram Elkhidir   Anas Marzouk  Editor Night Shift   Riyadh        رفض
#
#              Rejection      CompletionTime
# 4235                   2026-01-12 00:08:45
# 4238                   2026-01-12 00:09:55
# 4237                   2026-01-12 00:13:47
# 4236                   2026-01-12 00:26:02
# 4239    المخطط المعتمد 2026-01-12 00:33:39
# 4234  طلب لوحدة عقارية 2026-01-12 00:38:15

# %% [markdown]
# ### Detecting Missing Case Info

# %%
current_df = pd.read_sql("""SELECT * FROM grsdbrd."GeoData" WHERE "Transferred to Geospatial" = 'NaT' """, engine_sqlserver)
current = load_excel(r"\\10.150.40.49\las\Anas Alhares\NewTeam\E and C Final Folder 08092024\Case Editing and Classification\Editor Team\07-Raw Data\03-PBI Data\Geo data\Geo 2025-2026 (28-1-2026).xlsx")
current = current.drop_duplicates(subset="Case Number", keep='last')
current_null = current[current["Transferred to Geospatial"].isna()]
print(len(current_null), len(current_df))
# Out:
# 2 5969

# %%
current_df[current_df["Transferred to Geospatial"]=='NaT']
# Out:
#         Case Number Absolute Ownership Duplicate Case Generated Titles  \
# 0     FR20251005226               None           None             None
# 1     FR20251005506               None           None             None
# 2     FR20251005542               None           None             None
# 3     FR20251006160               None           None             None
# 4     FR20251006255               None           None             None
# ...             ...                ...            ...              ...
# 5964  FR20251002286               None           None             None
# 5965  FR20251002456               None           None             None
# 5966  FR20251003052               None           None             None
# 5967  FR20251004084               None           None             None
# 5968  FR20251004624               None           None             None
#
#      Case Submission Date Latest Action Date    Action Assignee  \
# 0              2025-11-24         2026-01-27  Geo Pool     None
# 1              2025-11-24         2026-01-27  Geo Pool     None
# 2              2025-11-24         2026-01-27  Geo Pool     None
# 3              2025-11-24         2026-01-27  Geo Pool     None
# 4              2025-11-24         2026-01-27  Geo Pool     None
# ...                   ...                ...       ...      ...
# 5964           2025-11-23         2026-01-27  Geo Pool     None
# 5965           2025-11-23         2026-01-27  Geo Pool     None
# 5966           2025-11-24         2026-01-27  Geo Pool     None
# 5967           2025-11-24         2026-01-27  Geo Pool     None
# 5968           2025-11-24         2026-01-27  Geo Pool     None
#
#      Transferred to Geospatial Return To Geo Team  ...  \
# 0                          NaT                 No  ...
# 1                          NaT                 No  ...
# 2                          NaT                 No  ...
# 3                          NaT                 No  ...
# 4                          NaT                 No  ...
# ...                        ...                ...  ...
# 5964                       NaT                 No  ...
# 5965                       NaT                 No  ...
# 5966                       NaT                 No  ...
# 5967                       NaT                 No  ...
# 5968                       NaT                 No  ...
#
#                                      CWS Recommendation    QC  \
# 0     assignCaseworker | للتحقق من الرسم على المخطط ...  None
# 1                                                  None  None
# 2                                                  None  None
# 3                                                  None  None
# 4                                                  None  None
# ...                                                 ...   ...
# 5964  assignCaseworker | الرجاء التحقق من ارفاق المر...  None
# 5965                                               None  None
# 5966                                               None  None
# 5967                                               None  None
# 5968                                               None  None
#
#      QC Recommendation              GEO GEO Recommendation  \
# 0                 None      Omar Jebrel           submit |
# 1                 None   Lamya Mohammed           submit |
# 2                 None   Lamya Mohammed           submit |
# 3                 None  Mohammed Sheikh           submit |
# 4                 None   Lamya Mohammed           submit |
# ...                ...              ...                ...
# 5964              None   Lamya Mohammed           submit |
# 5965              None   Lamya Mohammed           submit |
# 5966              None   Lamya Mohammed           submit |
# 5967              None   Lamya Mohammed           submit |
# 5968              None   Lamya Mohammed           submit |
#
#                 Geo Supervisor  \
# 0           Albaraa Aldurayhim
# 1                Mohamed Osman
# 2                Mohamed Osman
# 3     Mohammed Yousef Mohammed
# 4               Moataz Ibrahim
# ...                        ...
# 5964      Mohamed Hasabeldaeim
# 5965      Mohamed Hasabeldaeim
# 5966            Moataz Ibrahim
# 5967            Moataz Ibrahim
# 5968            Moataz Ibrahim
#
#                           Geo Supervisor Recommendation          UniqueKey  \
# 0     submit | يعاد الى مدقق الطلبات-خطأ في بيانات ا...  FR20251005226_NaT
# 1                                   submit | تم التجزئة  FR20251005506_NaT
# 2                    submit | تم تعديل البيانات الوصفية  FR20251005542_NaT
# 3     submit | تمت المعالجة بناءً على الوثيقة المرفق...  FR20251006160_NaT
# 4     submit | يعاد إلى مدقق الطلبات‑طلب تسجيل أول م...  FR20251006255_NaT
# ...                                                 ...                ...
# 5964  submit | علماً بان هناك اختلاف في الحد الغربي ...  FR20251002286_NaT
# 5965  submit | مع ملاحظة وجود اختلاف بين رقم المخطط ...  FR20251002456_NaT
# 5966  submit | تمت تجزئة القطع و ترقيمها بناء علي بي...  FR20251003052_NaT
# 5967  submit | يعاد الى مدقق الطلبات خطأ في الصك – ا...  FR20251004084_NaT
# 5968  submit | يعاد الى مدقق الطلبات-خطأ في بيانات ا...  FR20251004624_NaT
#
#       UploadDate UploadedBy
# 0     2026-01-28    Aaltoum
# 1     2026-01-28    Aaltoum
# 2     2026-01-28    Aaltoum
# 3     2026-01-28    Aaltoum
# 4     2026-01-28    Aaltoum
# ...          ...        ...
# 5964  2026-01-28    Aaltoum
# 5965  2026-01-28    Aaltoum
# 5966  2026-01-28    Aaltoum
# 5967  2026-01-28    Aaltoum
# 5968  2026-01-28    Aaltoum
#
# [5969 rows x 57 columns]

# %%
trans_date = current[current["Case Number"].isin(current_df["Case Number"])]
print(len(trans_date))
# Out:
# 5964

# %%
with engine_sqlserver.connect() as conn:
    for i, row in trans_date.iterrows():
        case_num = row["Case Number"]
        transDate = row["Transferred to Geospatial"].date()
        print(case_num, transDate)
        conn.execute(text(
        f"""UPDATE grsdbrd."GeoData" 
                SET "Transferred to Geospatial" = '{transDate}'
                WHERE "Case Number" = '{case_num}' """)),
                # {"transDate": transDate, "case_num": case_num}
        # )
        conn.commit()
    conn.close()
# Out:
# FR20251000884 2026-01-27
# FR20251001422 2025-12-17
# FR20251001827 2026-01-27
# FR20251002007 2026-01-27
# FR20251002044 2026-01-27
# FR20251002286 2026-01-27
# FR20251002456 2026-01-27
# FR20251003052 2026-01-27
# FR20251004084 2026-01-27
# FR20251004624 2026-01-27
# FR20251005226 2026-01-27
# FR20251005506 2026-01-27
# FR20251005542 2026-01-27
# FR20251006160 2026-01-27
# FR20251006255 2026-01-27
# FR20251006570 2026-01-27
# FR20251006668 2026-01-27
# FR20251006750 2026-01-27
# FR20251006951 2026-01-27
# FR20251007240 2026-01-27
# FR20251007633 2026-01-27
# FR20251007688 2026-01-27
# FR20251007837 2026-01-27
# FR20251008683 2026-01-26
# FR20251009026 2026-01-27
# FR20251009050 2026-01-27
# FR20251009620 2025-12-31
# FR20251009902 2026-01-27
# FR20251010355 2026-01-27
# FR20251010584 2026-01-27
# FR20251010919 2026-01-27
# FR20251011356 2025-12-10
# FR20251011420 2026-01-27
# FR20251011992 2026-01-27
# FR20251012070 2026-01-27
# FR20251012238 2026-01-27
# FR20251012313 2026-01-27
# FR20251012867 2026-01-27
# FR20251013026 2026-01-27
# FR20251013500 2026-01-27
# FR20251013604 2026-01-27
# FR20251013810 2026-01-27
# FR20251014632 2026-01-18
# 0  FR20251014416  7016606232100000         New  2025-11-25 22:14:12
# 1  FR20251024419  8417590859200000         New  2025-11-27 13:20:49
# 2  FR20251024556  2268198897100000         New  2025-11-27 13:41:02
# 3  FR20251025635  2449130825300000         New  2025-11-27 15:57:06
# 4  FR20251027153  5358118822300000         New  2025-11-27 19:46:17
#
#   Transferred to Geospatial      Latest Action Date LastImportDate    Action  \
# 0   2025-12-01 09:32:46.410                     NaT     2026-01-22  Geo Pool
# 1   2025-12-14 11:01:39.060                     NaT     2026-01-22  Geo Pool
# 2   2025-12-10 16:07:35.017 2026-01-26 09:34:08.373     2026-01-22  Geo Pool
# 3   2025-12-02 16:01:47.117                     NaT     2026-01-22  Geo Pool
# 4   2025-12-01 09:56:45.430 2026-01-22 16:00:16.523     2026-01-22  Geo Pool
#
#   Return To Geo Team  Count of Returns Cases  ...  Unnamed: 8  Unnamed: 9  \
# 0                 No                     1.0  ...         NaN         NaN
# 1                Yes                     2.0  ...         NaN         NaN
# 2                Yes                     2.0  ...         NaN         NaN
# 3                 No                     1.0  ...         NaN         NaN
# 4                 No                     1.0  ...         NaN         NaN
#
#    Unnamed: 10  Unnamed: 11  UserID.1 CasePortalName.1 GroupID.1  Unnamed: 12  \
# 0          NaN          NaN       NaN              NaN       NaN          NaN
# 1          NaN          NaN       NaN              NaN       NaN          NaN
# 2          NaN          NaN       NaN              NaN       NaN          NaN
# 3          NaN          NaN       NaN              NaN       NaN          NaN
# 4          NaN          NaN       NaN              NaN       NaN          NaN
#
#   Unnamed: 13 Unnamed: 14
# 0         NaN         NaN
# 1         NaN         NaN
# 2         NaN         NaN
# 3         NaN         NaN
# 4         NaN         NaN
#
# [5 rows x 48 columns]

# %%
cases_df.to_excel(r"\\10.150.40.49\las\Mutaz\Ayman\Hael_cases.xlsx", index=False)

# %%
cases = cases_df[["Case Number", "UserID", "CasePortalName"]]
cases
# Out:
#        Case Number        UserID     CasePortalName
# 0    FR20251014416   ralotaibi.c      Reem Alotaibi
# 1    FR20251024419      Ohamid.c         Omar Hamid
# 2    FR20251024556    Ialmudan.c      Ithar AlMudan
# 3    FR20251025635   Jaljasser.c    Jasser Aljasser
# 4    FR20251027153  falmarshed.c  Fatimah Almarshed
# ..             ...           ...                ...
# 159  FR20251092093      OSalah.c                NaN
# 160  FR20251092559      OSalah.c                NaN
# 161   FR2025995684    Aalotibi.c                NaN
# 162   FR2025996131       Madam.c      Mohammed Adam
# 163   FR2025998723    HShaaban.c     Husaam Shaaban
#
# [1152 rows x 3 columns]

# %%
cases = cases.drop_duplicates(subset=["Case Number", "UserID"])
len(cases)
# Out:
# 629

# %%
duplicates = cases[cases.duplicated(subset="Case Number")]
duplicates = duplicates.sort_values(by="Case Number")
duplicates
# Out:
#        Case Number       UserID    CasePortalName
# 4    FR20251010428    malnmar.c               NaN
# 21   FR20251010428    malnmar.c    Mustafa Alnmar
# 317  FR20251010616     Akamal.c       Ammar Kamal
# 6    FR20251010827    aaldeen.c               NaN
# 22   FR20251010827    aaldeen.c  Ahmed Dafaaldeen
# ..             ...          ...               ...
# 162   FR2025996131      Madam.c     Mohammed Adam
# 3     FR2025997642   MBarakat.c  Mohammed Barakat
# 1     FR2025998723  RAlharthi.c   Raseel Alharthi
# 163   FR2025998723   HShaaban.c    Husaam Shaaban
# 62    FR2025999524     MBaday.c     Mohamed Baday
#
# [531 rows x 3 columns]

# %%
duplicates[~duplicates["CasePortalName"].isna()]
# Out:
#        Case Number       UserID    CasePortalName
# 21   FR20251010428    malnmar.c    Mustafa Alnmar
# 317  FR20251010616     Akamal.c       Ammar Kamal
# 22   FR20251010827    aaldeen.c  Ahmed Dafaaldeen
# 310  FR20251010903     MBaday.c     Mohamed Baday
# 4    FR20251012056   AAltalhi.c      Amal Altalhi
# ..             ...          ...               ...
# 162   FR2025996131      Madam.c     Mohammed Adam
# 3     FR2025997642   MBarakat.c  Mohammed Barakat
# 1     FR2025998723  RAlharthi.c   Raseel Alharthi
# 163   FR2025998723   HShaaban.c    Husaam Shaaban
# 62    FR2025999524     MBaday.c     Mohamed Baday
#
# [447 rows x 3 columns]

# %%
cases = cases_df.drop_duplicates(subset="Case Number")
len(cases)
cases.to_excel(r"\\10.150.40.49\las\Mutaz\Ayman\Hael Cases - Unique.xlsx", index=False)

# %%
comp_df = pd.read_sql("""SELECT * FROM grsdbrd."GeoCompletion" 
                      WHERE "GEO S Completion" = '2026-01-27'
                      """, engine_sqlserver)
print(len(comp_df))
# Out:
# 3958

# %%
hael_cases = [str(i).strip() for i in cases["Case Number"].values]
print(len(hael_cases))
# Out:
# 621

# %%
hael_df = comp_df[comp_df["Case Number"].isin(hael_cases)]
print(len(hael_df))
# Out:
# 77

# %%
bulk = hael_df[hael_df["Geo Supervisor"]=='Moataz Ibrahim']

# %%
to_replace = cases[cases["Case Number"].isin(bulk["Case Number"])][["Case Number", "UserID"]]

# %%
editorList = pd.read_sql("SELECT * FROM evaluation.\"EditorsList\" ", engine_postgres2)

# %%
to_replace["Case Number"].tolist()
# Out:
# ['FR2025998723',
#  'FR20251012056',
#  'FR20251014869',
#  'FR20251015376',
#  'FR20251015490',
#  'FR20251016512',
#  'FR20251017030',
#  'FR20251018255',
#  'FR20251018569',
#  'FR20251021192',
#  'FR20251021281',
#  'FR20251010827',
#  'FR20251015110',
#  'FR20251016181',
#  'FR20251016774',
#  'FR20251016919',
#  'FR20251017393',
#  'FR20251017996',
#  'FR20251021833',
#  'FR20251016852',
#  'FR20251030134',
#  'FR20251032868',
#  'FR20251035522',
#  'FR2025999524',
#  'FR20251020781',
#  'FR20251024889',
#  'FR20251027529',
#  'FR20251030717',
#  'FR20251027502',
#  'FR20251034488']

# %%
to_replace = pd.merge(to_replace, editorList, on="UserID", how='inner')
print(len(to_replace))
to_replace.head()
# Out:
# 30
#      Case Number       UserID                    EditorName    CasePortalName  \
# 0   FR2025998723  RAlharthi.c               Raseel alharthi   Raseel Alharthi
# 1  FR20251012056   AAltalhi.c                  Amal Altalhi      Amal Altalhi
# 2  FR20251014869     MBaday.c  Mohamed Faisal Hussein Baday     Mohamed Baday
# 3  FR20251015376    malnmar.c               Mustafa Alnmar     Mustafa Alnmar
# 4  FR20251015490    aaldeen.c             Ahmed  Dafaaldeen  Ahmed Dafaaldeen
#
#    SupervisorID    SupervisorName               GroupID    ListDate  id
# 0      obakri.c       Osman Bakri  Support Team_Morning  2026-01-22  89
# 1       MLoay.c      Mohamed Loay  Support Team_Morning  2026-01-22  94
# 2  SAlfuraihi.c  Shaden Alfuraihi  Support Team_Morning  2026-01-22  92
# 3  SAlfuraihi.c  Shaden Alfuraihi  Support Team_Morning  2026-01-22  88
# 4      obakri.c       Osman Bakri  Support Team_Morning  2026-01-22  93

# %%
with engine_sqlserver.begin() as conn:
    for _, row in to_replace.iterrows():
        case_number = row["Case Number"]
        user_id = row["UserID"]
        name = row["EditorName"]
        g_name = row["CasePortalName"]
        sup = row["SupervisorName"]
        sup_id = row["SupervisorID"]
        group = row["GroupID"]
        query = text(
            f"""UPDATE GRSDBRD."GeoCompletion" 
            SET "Geo Supervisor" = '{g_name}',
            "EditorName" = '{name}',
            "UserID" = '{user_id}',
            "SupervisorID" = '{sup_id}',
            "SupervisorName" = '{sup}',
            "GroupID" = '{group}',
            "ListDate" = '2026-01-22'
            WHERE "Case Number" = '{case_number}'
            AND "Geo Supervisor" = 'Moataz Ibrahim' """
        )
        print(query)
        conn.execute(query)
    conn.commit()
    conn.close()
# Out:
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Raseel Alharthi',
#             "EditorName" = 'Raseel alharthi',
#             "UserID" = 'RAlharthi.c',
#             "SupervisorID" = 'obakri.c',
#             "SupervisorName" = 'Osman Bakri',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR2025998723'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Amal Altalhi',
#             "EditorName" = 'Amal Altalhi',
#             "UserID" = 'AAltalhi.c',
#             "SupervisorID" = 'MLoay.c',
#             "SupervisorName" = 'Mohamed Loay',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251012056'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Mohamed Baday',
#             "EditorName" = 'Mohamed Faisal Hussein Baday',
#             "UserID" = 'MBaday.c',
#             "SupervisorID" = 'SAlfuraihi.c',
#             "SupervisorName" = 'Shaden Alfuraihi',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251014869'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Mustafa Alnmar',
#             "EditorName" = 'Mustafa Alnmar ',
#             "UserID" = 'malnmar.c',
#             "SupervisorID" = 'SAlfuraihi.c',
#             "SupervisorName" = 'Shaden Alfuraihi',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251015376'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Ahmed Dafaaldeen',
#             "EditorName" = 'Ahmed  Dafaaldeen',
#             "UserID" = 'aaldeen.c',
#             "SupervisorID" = 'obakri.c',
#             "SupervisorName" = 'Osman Bakri',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251015490'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Raseel Alharthi',
#             "EditorName" = 'Raseel alharthi',
#             "UserID" = 'RAlharthi.c',
#             "SupervisorID" = 'obakri.c',
#             "SupervisorName" = 'Osman Bakri',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251016512'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Mohamed Baday',
#             "EditorName" = 'Mohamed Faisal Hussein Baday',
#             "UserID" = 'MBaday.c',
#             "SupervisorID" = 'SAlfuraihi.c',
#             "SupervisorName" = 'Shaden Alfuraihi',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251017030'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Amal Altalhi',
#             "EditorName" = 'Amal Altalhi',
#             "UserID" = 'AAltalhi.c',
#             "SupervisorID" = 'MLoay.c',
#             "SupervisorName" = 'Mohamed Loay',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251018255'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Ahmed Dafaaldeen',
#             "EditorName" = 'Ahmed  Dafaaldeen',
#             "UserID" = 'aaldeen.c',
#             "SupervisorID" = 'obakri.c',
#             "SupervisorName" = 'Osman Bakri',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251018569'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Amal Altalhi',
#             "EditorName" = 'Amal Altalhi',
#             "UserID" = 'AAltalhi.c',
#             "SupervisorID" = 'MLoay.c',
#             "SupervisorName" = 'Mohamed Loay',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251021192'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Raseel Alharthi',
#             "EditorName" = 'Raseel alharthi',
#             "UserID" = 'RAlharthi.c',
#             "SupervisorID" = 'obakri.c',
#             "SupervisorName" = 'Osman Bakri',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251021281'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Ahmed Dafaaldeen',
#             "EditorName" = 'Ahmed  Dafaaldeen',
#             "UserID" = 'aaldeen.c',
#             "SupervisorID" = 'obakri.c',
#             "SupervisorName" = 'Osman Bakri',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251010827'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Ahmed Dafaaldeen',
#             "EditorName" = 'Ahmed  Dafaaldeen',
#             "UserID" = 'aaldeen.c',
#             "SupervisorID" = 'obakri.c',
#             "SupervisorName" = 'Osman Bakri',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251015110'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Mohamed Baday',
#             "EditorName" = 'Mohamed Faisal Hussein Baday',
#             "UserID" = 'MBaday.c',
#             "SupervisorID" = 'SAlfuraihi.c',
#             "SupervisorName" = 'Shaden Alfuraihi',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251016181'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Raseel Alharthi',
#             "EditorName" = 'Raseel alharthi',
#             "UserID" = 'RAlharthi.c',
#             "SupervisorID" = 'obakri.c',
#             "SupervisorName" = 'Osman Bakri',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251016774'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Mohammed Alfathel',
#             "EditorName" = 'Mohammed Alfathel',
#             "UserID" = 'Malfathel.c',
#             "SupervisorID" = 'MAlsafi.c',
#             "SupervisorName" = 'Mosab Alsafi',
#             "GroupID" = 'Editor Morning Shift',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251016919'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Amal Altalhi',
#             "EditorName" = 'Amal Altalhi',
#             "UserID" = 'AAltalhi.c',
#             "SupervisorID" = 'MLoay.c',
#             "SupervisorName" = 'Mohamed Loay',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251017393'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Raseel Alharthi',
#             "EditorName" = 'Raseel alharthi',
#             "UserID" = 'RAlharthi.c',
#             "SupervisorID" = 'obakri.c',
#             "SupervisorName" = 'Osman Bakri',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251017996'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Ahmed Dafaaldeen',
#             "EditorName" = 'Ahmed  Dafaaldeen',
#             "UserID" = 'aaldeen.c',
#             "SupervisorID" = 'obakri.c',
#             "SupervisorName" = 'Osman Bakri',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251021833'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Mohammed Alfathel',
#             "EditorName" = 'Mohammed Alfathel',
#             "UserID" = 'Malfathel.c',
#             "SupervisorID" = 'MAlsafi.c',
#             "SupervisorName" = 'Mosab Alsafi',
#             "GroupID" = 'Editor Morning Shift',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251016852'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Mohamed Baday',
#             "EditorName" = 'Mohamed Faisal Hussein Baday',
#             "UserID" = 'MBaday.c',
#             "SupervisorID" = 'SAlfuraihi.c',
#             "SupervisorName" = 'Shaden Alfuraihi',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251030134'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Ahmed Dafaaldeen',
#             "EditorName" = 'Ahmed  Dafaaldeen',
#             "UserID" = 'aaldeen.c',
#             "SupervisorID" = 'obakri.c',
#             "SupervisorName" = 'Osman Bakri',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251032868'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Mohamed Baday',
#             "EditorName" = 'Mohamed Faisal Hussein Baday',
#             "UserID" = 'MBaday.c',
#             "SupervisorID" = 'SAlfuraihi.c',
#             "SupervisorName" = 'Shaden Alfuraihi',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251035522'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Mohamed Baday',
#             "EditorName" = 'Mohamed Faisal Hussein Baday',
#             "UserID" = 'MBaday.c',
#             "SupervisorID" = 'SAlfuraihi.c',
#             "SupervisorName" = 'Shaden Alfuraihi',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR2025999524'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Mohamed Baday',
#             "EditorName" = 'Mohamed Faisal Hussein Baday',
#             "UserID" = 'MBaday.c',
#             "SupervisorID" = 'SAlfuraihi.c',
#             "SupervisorName" = 'Shaden Alfuraihi',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251020781'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Raseel Alharthi',
#             "EditorName" = 'Raseel alharthi',
#             "UserID" = 'RAlharthi.c',
#             "SupervisorID" = 'obakri.c',
#             "SupervisorName" = 'Osman Bakri',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251024889'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Mohammed Badawi',
#             "EditorName" = 'Mohammed Badawi',
#             "UserID" = 'MBadawi.c',
#             "SupervisorID" = 'MAlsafi.c',
#             "SupervisorName" = 'Mosab Alsafi',
#             "GroupID" = 'Editor Morning Shift',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251027529'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Amal Altalhi',
#             "EditorName" = 'Amal Altalhi',
#             "UserID" = 'AAltalhi.c',
#             "SupervisorID" = 'MLoay.c',
#             "SupervisorName" = 'Mohamed Loay',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251030717'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Amal Altalhi',
#             "EditorName" = 'Amal Altalhi',
#             "UserID" = 'AAltalhi.c',
#             "SupervisorID" = 'MLoay.c',
#             "SupervisorName" = 'Mohamed Loay',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251027502'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'
# UPDATE GRSDBRD."GeoCompletion"
#             SET "Geo Supervisor" = 'Mohamed Baday',
#             "EditorName" = 'Mohamed Faisal Hussein Baday',
#             "UserID" = 'MBaday.c',
#             "SupervisorID" = 'SAlfuraihi.c',
#             "SupervisorName" = 'Shaden Alfuraihi',
#             "GroupID" = 'Support Team_Morning',
#             "ListDate" = '2026-01-22'
#             WHERE "Case Number" = 'FR20251034488'
#             AND "Geo Supervisor" = 'Moataz Ibrahim'

# %%
hael_df.groupby("Geo Supervisor").size().reset_index(name="Count")
# Out:
#           Geo Supervisor  Count
# 0       Abdullah AlMalki      4
# 1   Abdulrahman Alghamdi      3
# 2     Aboalhassan Shatir      2
# 3           Ahmed Siddig      2
# 4         Akram Elkhidir      2
# 5     Alsiddig Hassballa      5
# 6         Amal Almukhtar      1
# 7           Amal Altalhi      3
# 8           Amjad Alamri      1
# 9            Ammar Kamal      1
# 10     Fatimah Almarshed      6
# 11        Moataz Ibrahim     30
# 12          Moayed Magdy      1
# 13      Mohammad Ramdhan      1
# 14      Mohammed Barakat      4
# 15        Najah Almuteri      2
# 16        Omar Albuhayji      1
# 17       Raseel Alharthi      1
# 18         Reem Alotaibi      1
# 19         Samy Mohammed      1
# 20     Shouq S. Alghamdi      1
# 21     Sumayyh AlMuqayel      1
# 22         Waleed Hassan      3

# %%
hael_df.groupby("Geo Supervisor").size().reset_index(name="Count")
# Out:
#          Geo Supervisor  Count
# 0         AHMED Mahmmod      1
# 1   Abdulaziz Alhegbani      3
# 2     Abdulaziz alzuayr      1
# 3      Abdullah AlMalki      6
# 4      Abdullah Zamzami      1
# ..                  ...    ...
# 58    Renad Abdulrahman      1
# 59        Samy Mohammed      3
# 60    Shouq S. Alghamdi      1
# 61    Sumayyh AlMuqayel      3
# 62        Waleed Hassan      4
#
# [63 rows x 2 columns]

# %%
hael_df[~hael_df["Case Number"].isin(comp_df["Case Number"])]
# Out:
# Empty DataFrame
# Columns: [Case Number, Absolute Ownership, Duplicate Case, Generated Titles, Case Submission Date, Latest Action Date, Action, Assignee, Transferred to Geospatial, Return To Geo Team, Count of Returns Cases , GEO Completion, GEO S Completion, Transferred to Ops, Case Status, REN, Boundary Length Deed, Boundary Length Parcel, MoJ Deed Number, Moj Real Estate Serial, MoJ Plan #, MoJ Real Estate Area, MoJ Land Number, City Name, District Name, MoJ Deed Area Text, Property Type, Parcel Area Size, Parcel Number (PCP), Location Description, Attachments, Attachment Added Date, Deed East Limit Description, Deed East Limit Length, Deed Eastern Type, Deed  West Limit Description, Deed West Limit Length, Deed Western Boarder Type, Deed North Limit Description, Deed North Limit Length, Deed Northern Boarder Type, Deed South Limit Description, Deed South Limit Length, Deed Sothern Boarder Type, CW, CW Recommendation, CWS, CWS Recommendation, QC, QC Recommendation, GEO, GEO Recommendation, Geo Supervisor, Geo Supervisor Recommendation, UniqueKey, UploadDate, UploadedBy, Region, GeoAction, Rejection, SLA, EditorName, UserID, SupervisorID, SupervisorName, GroupID, ListDate]
# Index: []
#
# [0 rows x 67 columns]

# %% [markdown]
# ### Sara's Cases

# %%
comp = pd.read_sql("""SELECT * FROM GRSDBRD.GeoCompletion WHERE [Geo Supervisor] LIKE 'Sara Alsubaie'""", engine_sqlserver)
comp["Stamp"] = [pd.to_datetime(i.split('_')[1]) for i in comp["UniqueKey"]]

# %%
print(len(comp))
comp.head()
# Out:
# 2918
#     Case Number Absolute Ownership  Duplicate Case  Generated Titles  \
# 0  FR2024636029               None             0.0               0.0
# 1  FR2025129125               None             NaN               NaN
# 2  FR2025149474               None             0.0               0.0
# 3   FR202514954               None             NaN               NaN
# 4  FR2025158760               None             NaN               NaN
#
#   Case Submission Date Latest Action Date   Action Assignee  \
# 0           2024-12-09         2025-06-01  CW Pool     None
# 1           2025-02-06         2025-06-01  CW Pool     None
# 2           2025-02-11         2025-06-01  CW Pool     None
# 3           2025-01-05         2025-06-02  CW Pool     None
# 4           2025-02-13         2025-06-01  CW Pool     None
#
#   Transferred to Geospatial Return To Geo Team  ...  GeoAction  \
# 0                2025-05-18                Yes  ...        رفض
# 1                2025-05-15                Yes  ...        رفض
# 2                2025-05-19                Yes  ...        رفض
# 3                2025-05-13                Yes  ...        رفض
# 4                2025-05-20                Yes  ...        رفض
#
#         Rejection   SLA EditorName UserID SupervisorID  SupervisorName  \
# 0        صك الأرض  12.0       None   None         None            None
# 1     إختيار خاطئ  14.0       None   None         None            None
# 2     إختيار خاطئ  11.0       None   None         None            None
# 3     إختيار خاطئ  16.0       None   None         None            None
# 4  المخطط المعتمد  10.0       None   None         None            None
#
#    GroupID  ListDate               Stamp
# 0     None      None 2025-06-01 08:11:17
# 1     None      None 2025-06-01 13:46:08
# 2     None      None 2025-06-01 09:14:45
# 3     None      None 2025-06-01 08:19:36
# 4     None      None 2025-06-01 13:50:33
#
# [5 rows x 68 columns]

# %%
from datetime import time
sara1 = comp[(comp["Stamp"].dt.time >= time(5,30)) & (comp["Stamp"].dt.time < time(16,30))]
sara2 = comp[~comp["Case Number"].isin(sara1["Case Number"])]
print(len(sara1), len(sara2))
# Out:
# 2853 65

# %%
sara1.groupby("GEO S Completion").size().reset_index(name="Count")#.to_excel(r"C:\Users\Aaltoum\Documents\Sara J. Alsubaie.xlsx", index=False)
# Out:
#     GEO S Completion  Count
# 0         2025-05-25      6
# 1         2025-05-27      3
# 2         2025-05-28      1
# 3         2025-05-29     17
# 4         2025-05-31     10
# ..               ...    ...
# 139       2026-01-29     30
# 140       2026-02-01     30
# 141       2026-02-02     30
# 142       2026-02-03     15
# 143       2026-02-04     18
#
# [144 rows x 2 columns]

# %%
sara2_cases = sara2.groupby("GEO S Completion").size().reset_index(name="Count")#
sara2_cases
# Out:
#    GEO S Completion  Count
# 0        2025-08-21      1
# 1        2026-01-20      1
# 2        2026-01-22      3
# 3        2026-01-25      2
# 4        2026-01-26      9
# 5        2026-01-27     11
# 6        2026-01-28      3
# 7        2026-01-29      6
# 8        2026-02-01      9
# 9        2026-02-02      9
# 10       2026-02-03     10
# 11       2026-02-04      1

# %%
sara2.to_excel(r"C:\Users\Aaltoum\Documents\Sara J. Alsubaie.xlsx", index=False)

# %%
sara2 = sara2[sara2["GEO S Completion"]>= pd.to_datetime('2026-01-20').date()]
print(len(sara2))
# Out:
# 64

# %%
sara2[sara2["GEO S Completion"]>= pd.to_datetime('2026-01-28').date()]["Case Number"].tolist()
# Out:
# ['FR20251051879',
#  'FR20251054727',
#  'FR20251149447',
#  'FR20251205155',
#  'FR20251054758',
#  'FR20251119750',
#  'FR20251158879',
#  'FR20251078772',
#  'FR2025989135',
#  'FR20251078667',
#  'FR20251092145',
#  'FR20251139150',
#  'FR20251158879',
#  'FR20251165040',
#  'FR20251181282',
#  'FR20251192592',
#  'FR20251192715',
#  'FR20251226475',
#  'FR20251110807',
#  'FR20251116305',
#  'FR20251183177',
#  'FR20251200394',
#  'FR20251204889',
#  'FR20251205529',
#  'FR20251205621',
#  'FR20251215116',
#  'FR20251238933',
#  'FR20251176750',
#  'FR20251122650',
#  'FR20251152425',
#  'FR20251175141',
#  'FR20251204432',
#  'FR20251214469',
#  'FR20251214679',
#  'FR20251223265',
#  'FR20251273107',
#  'FR20251275333',
#  'FR20251148679']

# %%
sara1["Time"] = sara1["Stamp"].dt.time
sara1.head()
# Out:
# C:\Users\Aaltoum\AppData\Local\Temp\ipykernel_30140\4157154512.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   sara1["Time"] = sara1["Stamp"].dt.time
#         Case Number Absolute Ownership  Duplicate Case  Generated Titles  \
# 818    FR2025453840               None             0.0               0.0
# 2479  FR20251025819               None             0.0               0.0
# 2504  FR20251063348               None             NaN               NaN
# 2505  FR20251126953               None             NaN               NaN
# 2506  FR20251127071               None             NaN               NaN
#
#      Case Submission Date Latest Action Date   Action Assignee  \
# 818            2025-07-10         2025-08-21  CW Pool     None
# 2479           2025-11-27         2026-01-20  CW Pool     None
# 2504           2025-12-03         2026-01-27  CW Pool     None
# 2505           2025-12-16         2026-01-27  CW Pool     None
# 2506           2025-12-10         2026-01-27  CW Pool     None
#
#      Transferred to Geospatial Return To Geo Team  ...           Rejection  \
# 818                 2025-08-12                 No  ...      المخطط المعتمد
# 2479                2025-12-04                 No  ...            صك الأرض
# 2504                2025-12-14                 No  ...  محضر الدمج/التجزئة
# 2505                2026-01-04                 No  ...         إختيار خاطئ
# 2506                2025-12-12                 No  ...         إختيار خاطئ
#
#        SLA     EditorName        UserID SupervisorID SupervisorName  \
# 818    8.0           None          None         None           None
# 2479  34.0  Sara Alsubaie  SSalsubaie.c     obakri.c    Osman Bakri
# 2504  35.0  Sara Alsubaie  SSalsubaie.c     obakri.c    Osman Bakri
# 2505  20.0  Sara Alsubaie  SSalsubaie.c     obakri.c    Osman Bakri
# 2506  35.0  Sara Alsubaie  SSalsubaie.c     obakri.c    Osman Bakri
#
#                    GroupID    ListDate               Stamp      Time
# 818                   None        None 2025-08-21 20:56:47  20:56:47
# 2479  Editor Morning Shift  2026-01-19 2026-01-20 22:52:10  22:52:10
# 2504  Editor Morning Shift  2026-01-22 2026-01-27 23:19:36  23:19:36
# 2505  Editor Morning Shift  2026-01-22 2026-01-27 18:58:16  18:58:16
# 2506  Editor Morning Shift  2026-01-22 2026-01-27 18:57:29  18:57:29
#
# [5 rows x 69 columns]

# %%
sara1["Time"].min()
# Out:
# datetime.time(16, 48, 49)

# %%
sara1.to_excel(r"C:\Users\Aaltoum\Documents\Sara J. Alsubaie - Cases.xlsx", index=False)

# %% [markdown]
# ## Replacing Sara's Evaluation

# %%
cases_df = pd.read_sql("""SELECT * FROM grsdbrd."GeoCompletion" WHERE "Geo Supervisor" = 'Sara Jezaa Alsubaie' """, engine_sqlserver)
print(len(cases_df))
# Out:
# 132

# %%
assigned_cases = pd.read_sql("""SELECT * FROM evaluation."CaseAssignment" """, engine_postgres2)
cases_replace = assigned_cases[assigned_cases["UniqueKey"].isin(cases_df["UniqueKey"])]

# %%
print(len(cases_replace))
# Out:
# 22

# %%
cases_replace[cases_replace["EditorName"]=='Sara Alsubaie']["UniqueKey"].tolist()
# Out:
# ['FR20251005827_2026-01-22 17:22:07',
#  'FR20251088852_2026-01-26 00:17:28',
#  'FR20251264611_2026-01-27 00:00:09',
#  'FR20251063348_2026-01-27 23:19:36',
#  'FR2025989135_2026-01-29 00:00:50',
#  'FR20251051879_2026-01-29 16:48:49',
#  'FR20251158879_2026-02-01 18:40:36',
#  'FR20251176750_2026-02-03 00:00:16',
#  'FR20251116305_2026-02-02 17:15:05',
#  'FR20251148679_2026-02-04 16:56:59']

# %% [markdown]
# ## Arabic Names

# %%
file = r"D:\Unclassified\تصنيف الشهادات.xlsx"
df = pd.read_excel(file)

# %%
engine_ar = create_engine("postgresql://postgres:1234@localhost:5432/employeesdb")
data = pd.read_sql("""SELECT * FROM public."users" """, engine_ar)
print(len(data))
data.head()
# Out:
# 209
#    id       user_id                 full_name
# 0  10  nalsuhaimi.c     نوف جابر صالح السهيمي
# 1  11   Nalbalawi.c    نوف احمد فحيمان البلوي
# 2  12  aalmarzouq.c  الهنوف صالح ناصر المرزوق
# 3  13      Rharbi.c    رفال فهد صنيتان الحربي
# 4  14       MZaki.c     محمود زكي محمود عفيفي

# %%
df["UserID_lower"]= [i.lower() for i in df["UserID"]]
data["user_id_lower"] = [i.lower() for i in data["user_id"]]
df.head()
# Out:
#                EditorName-En         UserID Catogery   TeamID  \
# 0  Mohammed Ibrahim Mohammed    MMohammed.c      Gold  Urgent
# 1             Mahmoud Mamdoh      mmamdoh.c      Gold  Urgent
# 2             Reem Alzahrani   Ralzahrani.c      Gold     POD
# 3           Anwar Aljarallah  Aaljarallah.c      Gold  Urgent
# 4            Jasser Aljasser    Jaljasser.c      Gold  Urgent
#
#                     EditorName-Ar   UserID_lower
# 0       محمد ابراهيم عبدالله محمد    mmohammed.c
# 1  محمود ممدوح عبدالسلام عبدالخير      mmamdoh.c
# 2  ريم عبدالرحمن امبارك الزهراني    ralzahrani.c
# 3     انور حامد عبدالله الجارالله  aaljarallah.c
# 4       جاسر سعود عبدالله آل جاسر    jaljasser.c

# %%
not_inFile
# Out:
#       id        user_id                    full_name  user_id_lower
# 35    49   maboelmagd.c     محمود أبوالمجد عبدالرازق   maboelmagd.c
# 75     8         Iali.c     ابراهيم علي ابراهيم محمد         iali.c
# 95   113   FAlghorabe.c        فراس نبيل علي الغريبي   falghorabe.c
# 98   116    MAlnahari.c       منتهى زهير عمر النهاري    malnahari.c
# 122  140      AHazazi.c    عبدالوهاب يحيى هادي هزازي      ahazazi.c
# 144  163    AAlotaibi.c  عبدالاله مقعد مجلاد العتيبي    aalotaibi.c
# 178  209  AAlshamrani.c      أصيل سعيد محمد الشمراني  aalshamrani.c
# 184  215  GAlabdullah.c     غادة متعب بشير العبدالله  galabdullah.c
# 185  216  RAlshammari.c         رغد سلطان علي الشمري  ralshammari.c
# 187  218   WAlqadhibi.c  وليد سليمان عبدالله القضيبي   walqadhibi.c
# 188  219     YAlhamad.c      يوسف إبراهيم احمد الحمد     yalhamad.c
# 192  224  NAlmuwallad.c    نوف عبدالرحمن محسن المولد  nalmuwallad.c
# 193  225  NAbuthunayn.c       نورة متعب مفرج ابوثنين  nabuthunayn.c
# 203  197     qhussain.c                    قيصر نديم     qhussain.c
# 204  198        jkhan.c                     جلال خان        jkhan.c
# 207  220    MBIbrahim.c        منار بكر محمد ابراهيم    mbibrahim.c
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
not_inAr = df[~df["UserID_lower"].isin(data["user_id_lower"])]
not_inFile = data[~data["user_id_lower"].isin(df["UserID_lower"])]
print(len(not_inAr), len(not_inFile))
# Out:
# 26 16

# %%
not_inAr = not_inAr.rename(columns={"UserID":"user_id", "EditorName-Ar": "full_name"})
not_inAr
# Out:
#                  EditorName-En        user_id Catogery   \
# 2               Reem Alzahrani   Ralzahrani.c      Gold
# 5                Asmaa Alanazi     aalanazi.c    Silver
# 6              Nawaf Alrayyani   NAlrayyani.c    Silver
# 8               Muhanad Mansur      Mmansur.c    Silver
# 9               Norah Alfarraj    Nalfarraj.c    Silver
# 10              Aisha Alasmari    AAlasmari.c    Silver
# 11                Amr Alsanosy    aalsanosy.c    Silver
# 12           Wardah Alshahrani  walshahrani.c    Silver
# 13              Ahmed Alghamdi    aalghamdi.c    Silver
# 14                Hany Mansour     hmansour.c    Silver
# 15              Rehab Alghamdi    RAlghamdi.c    Silver
# 16              Abdullah Magdy       Amagdy.c    Silver
# 17            Meshari Alotaibi    Malotaibi.c    Bronze
# 19              Norah AlMaamar    NAlMaamar.c    Bronze
# 34    Tawfiq Samir Abd ELWAHAB     telwahab.c      Gold
# 38              Moataz Ibrahim     MIbrahim.c      Gold
# 39             Rowan Al-Subaie    RAlsubaie.c      Gold
# 58                 Ahmad Ishag       alshag.c      Gold
# 85             Bander AlHilali      Bhilali.c    Silver
# 90            Ghsoon Alsaggami   Galsaggami.c    Silver
# 139         Albaraa Aldurayhim  Aaldurayhim.c    Silver
# 184                 Ali Nasser      ANasser.c    Bronze
# 211          Abdullah alateer      aalateer.c      Null
# 213  Ftoon Bader Saad Alrawily    falrawily.c      Null
# 215                  Maldaly.c      MAldaly.c      Gold
# 216                  mhassan.c      MHassan.c      Gold
#
#                        TeamID                       full_name   UserID_lower
# 2                         POD  ريم عبدالرحمن امبارك الزهراني    ralzahrani.c
# 5                         POD         اسماء صغير مديفع العنزي     aalanazi.c
# 6                         POD         نواف ماجد عيسى الرياني    nalrayyani.c
# 8                         POD          مهند منصور احمد الجودي      mmansur.c
# 9                         POD     نوره صالح عبدالعزيز الفراج     nalfarraj.c
# 10                        POD        عائشه مانع محمد الأسمري     aalasmari.c
# 11                        POD          عمرو احمد السنوسي احمد    aalsanosy.c
# 12                        POD           وردة علي سعد الشهراني  walshahrani.c
# 13                        POD          احمد غازي عطيه الغامدي    aalghamdi.c
# 14                        POD          هاني محمد منصور الدهمه     hmansour.c
# 15                        POD         رحاب محمد احمد الغامدي     ralghamdi.c
# 16                        POD        عبدالله مجدي عبدالله شنب       amagdy.c
# 17                        POD        مشاري سلطان عيد العتيبي     malotaibi.c
# 19                        POD          نوره محمد فهد بن معمر     nalmaamar.c
# 34                    TRANING     توفيق سمير توفيق عبدالوهاب      telwahab.c
# 38                   REPORTER      معتز خلف الله محمد ابراهيم     mibrahim.c
# 39                Development  روان عبدالعزيز إبراهيم السبيعي    ralsubaie.c
# 58   Inquiry & Analysis_Night          احمد عثمان إسحاق مبارك       alshag.c
# 85            Subsequent Team      بندر عبدالله عبيد الهلالي       bhilali.c
# 90            Subsequent Team          غصون فهد محمد السقامي    galsaggami.c
# 139           Subsequent Team   البراء عبدالرحمن سعد الدريهم   aaldurayhim.c
# 184      Editor Morning Shift        علي احمد فتح الله الناصر      anasser.c
# 211                CORDINADOR         عبدالله محمد سالم العطر     aalateer.c
# 213                CORDINADOR           فتون بدر سعد الرويلي     falrawily.c
# 215                       POD          محمد مصطفى محمد الدالي      maldaly.c
# 216                       POD              مصعب حسن بابكر علي      mhassan.c

# %%
not_inAr[["user_id", "full_name"]].to_sql("users", engine_ar, if_exists='append', index=False)
# Out:
# 26

# %%
not_inAr#.loc[not_inAr["UserID"]=='MIbrahim.c',"EditorName-Ar"] = 'معتز خلف الله محمد ابراهيم'
# Out:
#                  EditorName-En         UserID Catogery   \
# 2               Reem Alzahrani   Ralzahrani.c      Gold
# 5                Asmaa Alanazi     aalanazi.c    Silver
# 6              Nawaf Alrayyani   NAlrayyani.c    Silver
# 8               Muhanad Mansur      Mmansur.c    Silver
# 9               Norah Alfarraj    Nalfarraj.c    Silver
# 10              Aisha Alasmari    AAlasmari.c    Silver
# 11                Amr Alsanosy    aalsanosy.c    Silver
# 12           Wardah Alshahrani  walshahrani.c    Silver
# 13              Ahmed Alghamdi    aalghamdi.c    Silver
# 14                Hany Mansour     hmansour.c    Silver
# 15              Rehab Alghamdi    RAlghamdi.c    Silver
# 16              Abdullah Magdy       Amagdy.c    Silver
# 17            Meshari Alotaibi    Malotaibi.c    Bronze
# 19              Norah AlMaamar    NAlMaamar.c    Bronze
# 34    Tawfiq Samir Abd ELWAHAB     telwahab.c      Gold
# 38              Moataz Ibrahim     MIbrahim.c      Gold
# 39             Rowan Al-Subaie    RAlsubaie.c      Gold
# 58                 Ahmad Ishag       alshag.c      Gold
# 85             Bander AlHilali      Bhilali.c    Silver
# 90            Ghsoon Alsaggami   Galsaggami.c    Silver
# 139         Albaraa Aldurayhim  Aaldurayhim.c    Silver
# 184                 Ali Nasser      ANasser.c    Bronze
# 211          Abdullah alateer      aalateer.c      Null
# 213  Ftoon Bader Saad Alrawily    falrawily.c      Null
# 215                  Maldaly.c      MAldaly.c      Gold
# 216                  mhassan.c      MHassan.c      Gold
#
#                        TeamID                   EditorName-Ar   UserID_lower
# 2                         POD  ريم عبدالرحمن امبارك الزهراني    ralzahrani.c
# 5                         POD         اسماء صغير مديفع العنزي     aalanazi.c
# 6                         POD         نواف ماجد عيسى الرياني    nalrayyani.c
# 8                         POD          مهند منصور احمد الجودي      mmansur.c
# 9                         POD     نوره صالح عبدالعزيز الفراج     nalfarraj.c
# 10                        POD        عائشه مانع محمد الأسمري     aalasmari.c
# 11                        POD          عمرو احمد السنوسي احمد    aalsanosy.c
# 12                        POD           وردة علي سعد الشهراني  walshahrani.c
# 13                        POD          احمد غازي عطيه الغامدي    aalghamdi.c
# 14                        POD          هاني محمد منصور الدهمه     hmansour.c
# 15                        POD         رحاب محمد احمد الغامدي     ralghamdi.c
# 16                        POD        عبدالله مجدي عبدالله شنب       amagdy.c
# 17                        POD        مشاري سلطان عيد العتيبي     malotaibi.c
# 19                        POD          نوره محمد فهد بن معمر     nalmaamar.c
# 34                    TRANING     توفيق سمير توفيق عبدالوهاب      telwahab.c
# 38                   REPORTER      معتز خلف الله محمد ابراهيم     mibrahim.c
# 39                Development  روان عبدالعزيز إبراهيم السبيعي    ralsubaie.c
# 58   Inquiry & Analysis_Night          احمد عثمان إسحاق مبارك       alshag.c
# 85            Subsequent Team      بندر عبدالله عبيد الهلالي       bhilali.c
# 90            Subsequent Team          غصون فهد محمد السقامي    galsaggami.c
# 139           Subsequent Team   البراء عبدالرحمن سعد الدريهم   aaldurayhim.c
# 184      Editor Morning Shift        علي احمد فتح الله الناصر      anasser.c
# 211                CORDINADOR         عبدالله محمد سالم العطر     aalateer.c
# 213                CORDINADOR           فتون بدر سعد الرويلي     falrawily.c
# 215                       POD          محمد مصطفى محمد الدالي      maldaly.c
# 216                       POD              مصعب حسن بابكر علي      mhassan.c

# %%
data = pd.read_sql("""SELECT * FROM public."users" """, engine_ar)

data.to_excel(r"D:\Unclassified\Employee Information\Arabic Names2.xlsx", index=False)# print(len(data))

# %% [markdown]
# ## ST Approved

# %%
cr = load_excel(r"D:\Dashboard\Data\Subsequent\2026-03-01\CR.xlsx")
mg = load_excel(r"D:\Dashboard\Data\Subsequent\2026-03-01\MG.xlsx")
sr = load_excel(r"D:\Dashboard\Data\Subsequent\2026-03-01\SR.xlsx")

# %%
import os
app_cr = cr[cr["Case Status"]=="Approved"]
app_cr = app_cr.drop_duplicates(subset="Case Number")
app_cr["REN"] = [str(i)[:16] for i in app_cr["REN"]]
app_cr["TransType"] = 'Correction'
app_cr["UniqueKey"] = [str(i)+'_'+str(pd.to_datetime(j).round('s')) for i,j in zip(app_cr["Case Number"].values, app_cr["Latest Action Date"].values)]
app_cr["UploadedBy"] = os.getlogin()
app_cr["UploadDate"] = datetime.now().date()

# %%
app_mg = mg[mg["Case Status"]=="Approved"]
app_mg = app_mg.drop_duplicates(subset="Case Number")
app_mg["REN"] = [str(i)[:16] for i in app_mg["REN"]]
app_mg["TransType"] = 'Merge'
app_mg["UniqueKey"] = [str(i)+'_'+str(pd.to_datetime(j).round('s')) for i,j in zip(app_mg["Case Number"].values, app_mg["Latest Action Date"].values)]
app_mg["UploadedBy"] = os.getlogin()
app_mg["UploadDate"] = datetime.now().date()

# %%
app_sr = sr[sr["Case Status"]=="Approved"]
app_sr = app_sr.drop_duplicates(subset="Case Number")
app_sr["REN"] = [str(i)[:16] for i in app_sr["REN"]]
app_sr["TransType"] = 'Split'
app_sr["UniqueKey"] = [str(i)+'_'+str(pd.to_datetime(j).round('s')) for i,j in zip(app_sr["Case Number"].values, app_sr["Latest Action Date"].values)]
app_sr["UploadedBy"] = os.getlogin()
app_sr["UploadDate"] = datetime.now().date()

# %%
len(app_cr), len(app_mg), len(app_sr)
# Out:
# (21259, 2315, 15739)

# %%
approved_st = pd.concat([app_cr, app_mg, app_sr])

# %%
approved_st.loc[approved_st["Region"]=='منطقة الرياض', "Region"] = 'Riyadh'
approved_st.loc[approved_st["Region"]=='منطقة القصيم', "Region"] = 'Qassim'
approved_st.loc[approved_st["Region"]=='المنطقة الشرقية', "Region"] = 'Eastern Province'
approved_st.loc[approved_st["Region"]=='منطقة مكة المكرمة', "Region"] = 'Makkah'
approved_st.loc[approved_st["Region"]=='منطقة حائل', "Region"] = 'Hail'
# approved_st.loc[approved_st["Region"]=='Hael', "Region"] = 'Hail'
approved_st.loc[approved_st["Region"]=='منطقة تبوك', "Region"] = 'Tabuk'
approved_st.loc[approved_st["Region"]=='منطقة المدينة المنورة', "Region"] = 'Medinah'

# %%
approved_st["Region"].unique()
# Out:
# array(['Riyadh', 'Eastern Province', 'Qassim', 'Madinah', 'Makkah',
#        'Hail', 'Northern Borders', 'Jawf', 'Medinah', 'Tabuk'],
#       dtype=object)

# %%
current_approved = pd.read_sql("""SELECT "Case Number" FROM public."ApprovedST" """, engine_postgres)

# %%
new_approved = approved_st[~approved_st["Case Number"].isin(current_approved["Case Number"])]
print(len(new_approved))
# Out:
# 192

# %%
new_approved.to_sql("ApprovedST", engine_postgres, schema='public', if_exists='append', index=False)
# Out:
# 192
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %% [markdown]
# ### Mazin's Team

# %%
import os
dir = r"D:\Unclassified\New Teams\Mazin\All data"
files = [i for i in os.listdir(dir)]

# %%
xlsFiles = [i for i in files if i.endswith('.xlsx')]
csvFiles = [i for i in files if i.endswith('.csv')]
print(xlsFiles)
# Out:
# ['Norah_cases-2026-02-23.xlsx', 'Norah_cases-2026-02-24.xlsx', 'Norah_cases-2026-02-25.xlsx', 'Norah_cases-2026-02-26.xlsx', 'Norah_cases-2026-02-28.xlsx', 'Raghad_28-02-2026.xlsx']

# %%
dfs1 = []
for i in xlsFiles:
    parsed = i.split('_')
    print(parsed)
    name = parsed[0]
    date = pd.to_datetime(parsed[1].replace('cases-','').replace('.xlsx','')).date()
    print(name, date)
    df = pd.read_excel('/'.join([dir, i]), skiprows=1)
    df['Editor'] = name
    df["Case Date"] = date
    df = df.rename(columns={"FR": "Case Number"})
    # print(df.head())
    
    dfs1.append(df)
# Out:
# ['Norah', 'cases-2026-02-23.xlsx']
# Norah 2026-02-23
# ['Norah', 'cases-2026-02-24.xlsx']
# Norah 2026-02-24
# ['Norah', 'cases-2026-02-25.xlsx']
# Norah 2026-02-25
# ['Norah', 'cases-2026-02-26.xlsx']
# Norah 2026-02-26
# ['Norah', 'cases-2026-02-28.xlsx']
# Norah 2026-02-28
# ['Raghad', '28-02-2026.xlsx']
# Raghad 2026-02-28
# C:\Users\Aaltoum\AppData\Local\Temp\ipykernel_48712\2274939712.py:6: UserWarning: Parsing dates in %d-%m-%Y format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   date = pd.to_datetime(parsed[1].replace('cases-','').replace('.xlsx','')).date()

# %%
dfs2 = []
for i in csvFiles[2:]:
    fileName = i.replace('cases_','').replace('.csv','')
    print(fileName)
    parsed = fileName.split('_')
    print(parsed)
    name = parsed[0]
    # date = pd.to_datetime(parsed[1]).date()
    print(name, date)
    df = pd.read_csv('/'.join([dir, i]), skiprows=0)
    df['Editor'] = name
    df = df.rename(columns={"Case ID": "Case Number"})
    # df["Date"] = date
    print(df.head())
    
    dfs2.append(df)
# Out:
# Nouf_2026-02-23
# ['Nouf', '2026-02-23']
# Nouf 2026-02-28
#     Case Date  Case #    Case Number  \
# 0  2026-02-23       1  FR20251238174
# 1  2026-02-23       2  FR20251070460
# 2  2026-02-23       3  FR20251210558
# 3  2026-02-23       4  FR20251470235
# 4  2026-02-23       5  FR20251375178
#
#                                           Case Notes Editor
# 0  يعاد الى مدقق الطلبات-الارض المختارة غير صحيحة...   Nouf
# 1  يعاد الى مدقق الطلبات – نقص مستندات – محضر الل...   Nouf
# 2  يعاد الى مدقق الطلبات – نقص مستندات – محضر الل...   Nouf
# 3  يعاد الى مدقق الطلبات-نقص المستندات-ارفاق كافة...   Nouf
# 4  يعاد الى مدقق الطلبات –  بيانات الصك غير مطابق...   Nouf
# Nouf_2026-02-24
# ['Nouf', '2026-02-24']
# Nouf 2026-02-28
#     Case Date  Case #    Case Number  \
# 0  2026-02-24       1  FR20251085518
# 1  2026-02-24       2   FR2025946000
# 2  2026-02-24       3  FR20251285467
# 3  2026-02-24       4  FR20251258812
# 4  2026-02-24       5  FR20251244135
#
#                                           Case Notes Editor
# 0  يعاد الى مدقق الطلبات –  بيانات الصك غير مطابق...   Nouf
# 1  يعاد الى مدقق الطلبات – نقص مستندات – محضر الل...   Nouf
# 2  تم تعديل البيانات الوصفية-تم الترقيم بناء على ...   Nouf
# 3  يعاد الى مدقق الطلبات – نقص مستندات – محضر الل...   Nouf
# 4  تم تعديل البيانات الوصفية-تم تعديل البيانات ال...   Nouf
# Nouf_2026-02-25
# ['Nouf', '2026-02-25']
# Nouf 2026-02-28
#     Case Date  Case #    Case Number  \
# 0  2026-02-25       1  FR20251012976
# 1  2026-02-25       2  FR20251033296
# 2  2026-02-25       3  FR20251225029
# 3  2026-02-25       4   FR2025993086
# 4  2026-02-25       5   FR2025918511
#
#                                           Case Notes Editor
# 0  تم الدمج-الصك متعدد ولا يتوفر كافة المؤشرات-تم...   Nouf
# 1  يعاد الى مدقق الطلبات –  بيانات الصك غير مطابق...   Nouf
# 2  يعاد الى مدقق الطلبات-نقص في المستندات-صك الار...   Nouf
# 3  تم الدمج-تم الدمج و تم المعالجة بناء على توجيه...   Nouf
# 4  تم الدمج-تم الدمج وتم المعالجة بناء على توجيه ...   Nouf
# Raghad_23-02-2026
# ['Raghad', '23-02-2026']
# Raghad 2026-02-28
#     Case Date  Case #    Case Number  \
# 0  2026-02-23       1  FR20251246139
# 1  2026-02-23       2  FR20251231320
# 2  2026-02-23       3  FR20251239111
# 3  2026-02-23       4  FR20251217249
# 4  2026-02-23       5  FR20251394330
#
#                                           Case Notes  Editor
# 0  يعاد الى مدقق الطلبات-نقص المستندات-ارفاق كافة...  Raghad
# 1  يعاد الى مدقق الطلبات-الارض المختارة غير صحيحة...  Raghad
# 2  يعاد الى مدقق الطلبات-نقص في المستندات-صك الار...  Raghad
# 3  تم تعديل البيانات الوصفية-تم تعديل البيانات ال...  Raghad
# 4  يعاد الى مدقق الطلبات – نقص مستندات – المخطط ا...  Raghad
# Raghad_24-02-2026
# ['Raghad', '24-02-2026']
# Raghad 2026-02-28
#     Case Date  Case #    Case Number  \
# 0  2026-02-24       1  FR20251410232
# 1  2026-02-24       2  FR20251341934
# 2  2026-02-24       3  FR20251333663
# 3  2026-02-24       4  FR20251353880
#
#                                           Case Notes  Editor
# 0  يعاد الى مدقق الطلبات –  بيانات الصك غير مطابق...  Raghad
# 1          تم تعديل ابعاد الارض-تم تعديل ابعاد الارض  Raghad
# 2          تم تعديل ابعاد الارض-تم تعديل ابعاد الارض  Raghad
# 3  يعاد الى مدقق الطلبات –  بيانات الصك غير مطابق...  Raghad

# %%
dfs_1 = pd.concat(dfs1)
dfs_2 = pd.concat(dfs2)
dfs = pd.concat([dfs_1, dfs_2])
dfs
# Out:
#       #    Case Number                                         Case Notes  \
# 0   1.0   FR2025880064    يعاد إلى مدقق الطلبات-نقص في المستندات-صك الأرض
# 1   2.0  FR20251197789   يعاد إلى مدقق الطلبات-البيانات الجيومكانية صحيحة
# 2   3.0  FR20251246012  تم تعديل البيانات الوصفية,تم الترقيم بناء على ...
# 0   1.0  FR20251291806                          تم تعديل البيانات الوصفية
# 1   2.0  FR20251302695  يعاد الى مدقق الطلبات – نقص مستندات – محضر الل...
# ..  ...            ...                                                ...
# 4   NaN  FR20251394330  يعاد الى مدقق الطلبات – نقص مستندات – المخطط ا...
# 0   NaN  FR20251410232  يعاد الى مدقق الطلبات –  بيانات الصك غير مطابق...
# 1   NaN  FR20251341934          تم تعديل ابعاد الارض-تم تعديل ابعاد الارض
# 2   NaN  FR20251333663          تم تعديل ابعاد الارض-تم تعديل ابعاد الارض
# 3   NaN  FR20251353880  يعاد الى مدقق الطلبات –  بيانات الصك غير مطابق...
#
#     Editor   Case Date  Case #
# 0    Norah  2026-02-23     NaN
# 1    Norah  2026-02-23     NaN
# 2    Norah  2026-02-23     NaN
# 0    Norah  2026-02-24     NaN
# 1    Norah  2026-02-24     NaN
# ..     ...         ...     ...
# 4   Raghad  2026-02-23     5.0
# 0   Raghad  2026-02-24     1.0
# 1   Raghad  2026-02-24     2.0
# 2   Raghad  2026-02-24     3.0
# 3   Raghad  2026-02-24     4.0
#
# [75 rows x 6 columns]

# %%
# dfs = dfs.drop(columns=["UserID","EditorName", "SupervisorID","SupervisorName","GroupID","ListDate"])

# %%
dfs.loc[dfs["Editor"]=='Raghad', "Editor"] = 'Raghad Alshammari'
dfs.loc[dfs["Editor"]=='Norah', "Editor"] = 'Norah Muteb'
dfs.loc[dfs["Editor"]=='Nouf', "Editor"] = 'Nouf Almuwallad'

# %%
len(dfs)
# Out:
# 75

# %%
editors = pd.read_sql(f"""SELECT * FROM evaluation."EditorsList" 
                      WHERE "CasePortalName" IN ({str(dfs["Editor"].unique().tolist()).strip('[]')}) """, engine_postgres2)
editors
# Out:
#                     EditorName     CasePortalName         UserID  \
# 0     Raghad Sultan Alshammari  Raghad Alshammari  RAlshammari.c
# 1  Nouf Abdulrahman Almuwallad    Nouf Almuwallad  NAlmuwallad.c
# 2      Norah Muteb Abu Thunayn        Norah Muteb  NAbuthunayn.c
#
#       SupervisorID      SupervisorName             GroupID    ListDate
# 0  MMohammedKhir.c  Mazin MohammedKhir  Editor Night Shift  2026-02-15
# 1  MMohammedKhir.c  Mazin MohammedKhir  Editor Night Shift  2026-02-15
# 2  MMohammedKhir.c  Mazin MohammedKhir  Editor Night Shift  2026-02-15

# %%
merged = pd.merge(dfs, editors, left_on="Editor", right_on="CasePortalName", how='left')
print(len(merged))
merged.head()
# Out:
# 75
#      #    Case Number                                         Case Notes  \
# 0  1.0   FR2025880064    يعاد إلى مدقق الطلبات-نقص في المستندات-صك الأرض
# 1  2.0  FR20251197789   يعاد إلى مدقق الطلبات-البيانات الجيومكانية صحيحة
# 2  3.0  FR20251246012  تم تعديل البيانات الوصفية,تم الترقيم بناء على ...
# 3  1.0  FR20251291806                          تم تعديل البيانات الوصفية
# 4  2.0  FR20251302695  يعاد الى مدقق الطلبات – نقص مستندات – محضر الل...
#
#         Editor   Case Date  Case #               EditorName CasePortalName  \
# 0  Norah Muteb  2026-02-23     NaN  Norah Muteb Abu Thunayn    Norah Muteb
# 1  Norah Muteb  2026-02-23     NaN  Norah Muteb Abu Thunayn    Norah Muteb
# 2  Norah Muteb  2026-02-23     NaN  Norah Muteb Abu Thunayn    Norah Muteb
# 3  Norah Muteb  2026-02-24     NaN  Norah Muteb Abu Thunayn    Norah Muteb
# 4  Norah Muteb  2026-02-24     NaN  Norah Muteb Abu Thunayn    Norah Muteb
#
#           UserID     SupervisorID      SupervisorName             GroupID  \
# 0  NAbuthunayn.c  MMohammedKhir.c  Mazin MohammedKhir  Editor Night Shift
# 1  NAbuthunayn.c  MMohammedKhir.c  Mazin MohammedKhir  Editor Night Shift
# 2  NAbuthunayn.c  MMohammedKhir.c  Mazin MohammedKhir  Editor Night Shift
# 3  NAbuthunayn.c  MMohammedKhir.c  Mazin MohammedKhir  Editor Night Shift
# 4  NAbuthunayn.c  MMohammedKhir.c  Mazin MohammedKhir  Editor Night Shift
#
#      ListDate
# 0  2026-02-15
# 1  2026-02-15
# 2  2026-02-15
# 3  2026-02-15
# 4  2026-02-15

# %%
with engine_sqlserver.begin() as conn:
        
    notFound = []
    found = []
    morethan1 = []
    for _, row in merged.iterrows():
        # print(row)
        case_num = row["Case Number"].strip()
        editorName = row["EditorName"]
        user_id= row["UserID"]
        sup_id= row["SupervisorID"]
        sup_name= row["SupervisorName"]
        group_id= row["GroupID"] 
        list_date = row["ListDate"]
        case_date = row["Case Date"]
        check_query = f"""
            SELECT * FROM GRSDBRD."GeoCompletion"
            WHERE "Case Number" = '{case_num}' -- AND "GEO S Completion" = '{case_date}'
            AND "Geo Supervisor" = 'Mazin MohammedKhir'
        """
        casesFound = len(pd.read_sql(check_query, engine_sqlserver))
        print(f"There {casesFound} cases found for FR: {case_num}")
        if casesFound == 1:
            found.append(case_num)
            query=f"""
            UPDATE GRSDBRD."GeoCompletion" 
                SET "EditorName" = '{editorName}',
                "UserID" = '{user_id}',
                "SupervisorID" = '{sup_id}',
                "SupervisorName" = '{sup_name}',
                "GroupID" = '{group_id}',
                "ListDate" = '{list_date}'
            WHERE "Case Number" = '{case_num}' -- AND "GEO S Completion" = '{case_date}'
            AND "Geo Supervisor" = 'Mazin MohammedKhir'
            """
            print(query)
            # conn.execute(text(query))
        else:
            if casesFound >1: morethan1.append(case_num)
            else: notFound.append(case_num)
# Out:
# There 0 cases found for FR: FR2025880064
# There 0 cases found for FR: FR20251197789
# There 0 cases found for FR: FR20251246012
# There 0 cases found for FR: FR20251291806
# There 0 cases found for FR: FR20251302695
# There 0 cases found for FR: FR20251302091
# There 0 cases found for FR: FR20251302583
# There 0 cases found for FR: FR20251302391
# There 0 cases found for FR: FR20251265196
# There 0 cases found for FR: FR20251231230
